# %% [markdown]
# > #### This notebook is forked from Randy Lao a great guy in Data science Communities. I just tried review his work and add some more in it. But it is super notebook.
#
#
# PASSNYC uses public data to identify students within New York City’s under-performing school districts and, through consulting and collaboration with partners, aims to increase the diversity of students taking the Specialized High School Admissions Test (SHSAT). By focusing efforts in under-performing areas that are historically underrepresented in SHSAT registration, we will help pave the path to specialized high schools for a more diverse group of students.

# %% [markdown]
# # The Problem
# ***
#
#
# 1. **Low Number of Black and Latino Students** in specialized High Schools.
# 2. Only 10% of New York City's public school students are black/latino received offers, even though 67% of public students are black/latino
# 3. Asians make up **62%** of students at specialized high schools, even though 16% of public students are asian
# 4. Whites make up **24%** of students at specialized highs schools, even though 15% of public students are white
#
# **Hypothesis:**
# Before we begin doing any analysis, it's always best to have some ideas in mind to understand why underrepresented groups of students are not receiving the help they need. Here are a few ideas:
# - **Community VS Non-Community** schools should have an impact to the type of students
# - **Race** can be a proxy for a student's need of help, this is very debatable
# - A school's **location** can be a proxy for students in need of help
# - Student overall **performance** per school can be a proxy as well

# %% [markdown]
# ### Dataset divisions
#
# 1. New York City SAT Results:
# From New York City Open Data
#
# 2. NY 2010 - 2016 School Safety Report:
# From New York City Open Data
#
# 3. NYS NYSERDA Low-to-Moderate-Income Census Populat:
# From New York State Open Data
#
# 4. PASSNYC: Data Science for Good Challenge:
# Help PASSNYC determine which schools need their services the most

# %% [markdown]
# # Exploratory Data Analysis of New York Schools
# ***

# %%
# Import the neccessary modules for data manipulation and visual representation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)  



df = pd.read_csv('2016 School Explorer.csv')
shsat = pd.read_csv('D5 SHSAT Registrations and Testers.csv')

safety = pd.read_csv('2010-2016-school-safety-report.csv')

# %%
df.tail()
# Out:
#      Adjusted Grade New? Other Location Code in LCGMS  \
# 1267            NaN  NaN                          NaN
# 1268            NaN  NaN                          NaN
# 1269            NaN  NaN                          NaN
# 1270            NaN  NaN                          NaN
# 1271            NaN  NaN                          NaN
#
#                                    School Name      SED Code Location Code  \
# 1267        FAMILY LIFE ACADEMY CHARTER SCHOOL  320900860839        84X705
# 1268             HARRIET TUBMAN CHARTER SCHOOL  320900860823        84X706
# 1269                      ICAHN CHARTER SCHOOL  320900860835        84X717
# 1270  BRONX CHARTER SCHOOL FOR BETTER LEARNING  321100860855        84X718
# 1271         BRONX CHARTER SCHOOL FOR THE ARTS  320800860846        84X730
#
#       District   Latitude  Longitude  \
# 1267         9  40.840277 -73.918654
# 1268         9  40.832272 -73.905817
# 1269         9  40.839176 -73.904982
# 1270        11  40.888739 -73.847787
# 1271         8  40.821798 -73.886463
#
#                                  Address (Full)   City    Zip  \
# 1267              14 W 170TH ST BRONX, NY 10452  BRONX  10452
# 1268               3565 3RD AVE BRONX, NY 10456  BRONX  10456
# 1269             1525 BROOK AVE BRONX, NY 10457  BRONX  10457
# 1270  3740 BAYCHESTER AVE ANNEX BRONX, NY 10466  BRONX  10466
# 1271         950 LONGFELLOW AVE BRONX, NY 10474  BRONX  10474
#
#                           Grades Grade Low Grade High Community School?  \
# 1267           0K,01,02,03,04,05        0K         05                No
# 1268  0K,01,02,03,04,05,06,07,08        0K         08                No
# 1269  0K,01,02,03,04,05,06,07,08        0K         08                No
# 1270           0K,01,02,03,04,05        0K         05                No
# 1271        0K,01,02,03,04,05,06        0K         06                No
#
#       Economic Need Index School Income Estimate Percent ELL Percent Asian  \
# 1267                0.832            $27,243.69          19%            0%
# 1268                0.825            $24,172.46          11%            0%
# 1269                0.724            $26,422.05           2%            0%
# 1270                0.544            $47,192.42           2%            2%
# 1271                0.840            $29,096.71          15%            1%
#
#      Percent Black Percent Hispanic Percent Black / Hispanic Percent White  \
# 1267           20%              77%                      97%            1%
# 1268           68%              31%                      98%            1%
# 1269           54%              45%                      99%            1%
# 1270           86%               9%                      95%            1%
# 1271           28%              67%                      96%            2%
#
#      Student Attendance Rate Percent of Students Chronically Absent  \
# 1267                     95%                                    13%
# 1268                     94%                                    24%
# 1269                     95%                                    12%
# 1270                     95%                                    12%
# 1271                     93%                                    22%
#
#      Rigorous Instruction % Rigorous Instruction Rating  \
# 1267                    94%            Exceeding Target
# 1268                    93%              Meeting Target
# 1269                    97%            Exceeding Target
# 1270                    93%              Meeting Target
# 1271                    87%          Approaching Target
#
#      Collaborative Teachers % Collaborative Teachers Rating  \
# 1267                      93%              Exceeding Target
# 1268                      90%                Meeting Target
# 1269                      92%              Exceeding Target
# 1270                      91%                Meeting Target
# 1271                      84%                Meeting Target
#
#      Supportive Environment % Supportive Environment Rating  \
# 1267                      94%              Exceeding Target
# 1268                      88%                Meeting Target
# 1269                      89%                Meeting Target
# 1270                      96%              Exceeding Target
# 1271                      84%            Approaching Target
#
#      Effective School Leadership % Effective School Leadership Rating  \
# 1267                           88%                     Meeting Target
# 1268                           88%                   Exceeding Target
# 1269                           84%                     Meeting Target
# 1270                           89%                   Exceeding Target
# 1271                           77%                     Meeting Target
#
#      Strong Family-Community Ties % Strong Family-Community Ties Rating  \
# 1267                            83%                      Meeting Target
# 1268                            88%                      Meeting Target
# 1269                            86%                      Meeting Target
# 1270                            91%                    Exceeding Target
# 1271                            85%                      Meeting Target
#
#      Trust %        Trust Rating Student Achievement Rating  \
# 1267     94%      Meeting Target             Meeting Target
# 1268     93%      Meeting Target             Meeting Target
# 1269     94%      Meeting Target             Meeting Target
# 1270     95%    Exceeding Target             Meeting Target
# 1271     84%  Approaching Target           Exceeding Target
#
#       Average ELA Proficiency  Average Math Proficiency  \
# 1267                     2.48                      2.60
# 1268                     2.50                      2.85
# 1269                     2.77                      3.09
# 1270                     2.60                      3.29
# 1271                     2.74                      3.19
#
#       Grade 3 ELA - All Students Tested  Grade 3 ELA 4s - All Students  \
# 1267                                 52                              2
# 1268                                 75                              5
# 1269                                 35                              3
# 1270                                 72                              2
# 1271                                 50                              6
#
#       Grade 3 ELA 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 3 ELA 4s - Black or African American  \
# 1267                                           0
# 1268                                           2
# 1269                                           2
# 1270                                           2
# 1271                                           1
#
#       Grade 3 ELA 4s - Hispanic or Latino  \
# 1267                                    2
# 1268                                    3
# 1269                                    1
# 1270                                    0
# 1271                                    5
#
#       Grade 3 ELA 4s - Asian or Pacific Islander  Grade 3 ELA 4s - White  \
# 1267                                           0                       0
# 1268                                           0                       0
# 1269                                           0                       0
# 1270                                           0                       0
# 1271                                           0                       0
#
#       Grade 3 ELA 4s - Multiracial  \
# 1267                             0
# 1268                             0
# 1269                             0
# 1270                             0
# 1271                             0
#
#       Grade 3 ELA 4s - Limited English Proficient  \
# 1267                                            0
# 1268                                            0
# 1269                                            0
# 1270                                            0
# 1271                                            0
#
#       Grade 3 ELA 4s - Economically Disadvantaged  \
# 1267                                            2
# 1268                                            3
# 1269                                            0
# 1270                                            1
# 1271                                            5
#
#       Grade 3 Math - All Students tested  Grade 3 Math 4s - All Students  \
# 1267                                  52                              10
# 1268                                  75                              41
# 1269                                  35                               7
# 1270                                  72                              14
# 1271                                  50                              25
#
#       Grade 3 Math 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 3 Math 4s - Black or African American  \
# 1267                                            0
# 1268                                           26
# 1269                                            3
# 1270                                           14
# 1271                                            4
#
#       Grade 3 Math 4s - Hispanic or Latino  \
# 1267                                    10
# 1268                                    15
# 1269                                     4
# 1270                                     0
# 1271                                    20
#
#       Grade 3 Math 4s - Asian or Pacific Islander  Grade 3 Math 4s - White  \
# 1267                                            0                        0
# 1268                                            0                        0
# 1269                                            0                        0
# 1270                                            0                        0
# 1271                                            0                        0
#
#       Grade 3 Math 4s - Multiracial  \
# 1267                              0
# 1268                              0
# 1269                              0
# 1270                              0
# 1271                              0
#
#       Grade 3 Math 4s - Limited English Proficient  \
# 1267                                             1
# 1268                                             0
# 1269                                             0
# 1270                                             0
# 1271                                             0
#
#       Grade 3 Math 4s - Economically Disadvantaged  \
# 1267                                             9
# 1268                                            29
# 1269                                             0
# 1270                                            10
# 1271                                            19
#
#       Grade 4 ELA - All Students Tested  Grade 4 ELA 4s - All Students  \
# 1267                                 52                              6
# 1268                                 74                             11
# 1269                                 34                              9
# 1270                                 65                              3
# 1271                                 49                              7
#
#       Grade 4 ELA 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 4 ELA 4s - Black or African American  \
# 1267                                           0
# 1268                                           7
# 1269                                           6
# 1270                                           2
# 1271                                           2
#
#       Grade 4 ELA 4s - Hispanic or Latino  \
# 1267                                    5
# 1268                                    0
# 1269                                    3
# 1270                                    0
# 1271                                    5
#
#       Grade 4 ELA 4s - Asian or Pacific Islander  Grade 4 ELA 4s - White  \
# 1267                                           0                       0
# 1268                                           0                       0
# 1269                                           0                       0
# 1270                                           0                       0
# 1271                                           0                       0
#
#       Grade 4 ELA 4s - Multiracial  \
# 1267                             0
# 1268                             0
# 1269                             0
# 1270                             0
# 1271                             0
#
#       Grade 4 ELA 4s - Limited English Proficient  \
# 1267                                            0
# 1268                                            0
# 1269                                            0
# 1270                                            0
# 1271                                            0
#
#       Grade 4 ELA 4s - Economically Disadvantaged  \
# 1267                                            0
# 1268                                            7
# 1269                                            0
# 1270                                            2
# 1271                                            7
#
#       Grade 4 Math - All Students Tested  Grade 4 Math 4s - All Students  \
# 1267                                  52                              17
# 1268                                  75                              18
# 1269                                  34                               9
# 1270                                  65                              16
# 1271                                  49                               9
#
#       Grade 4 Math 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 4 Math 4s - Black or African American  \
# 1267                                            0
# 1268                                           14
# 1269                                            5
# 1270                                           15
# 1271                                            2
#
#       Grade 4 Math 4s - Hispanic or Latino  \
# 1267                                    12
# 1268                                     0
# 1269                                     4
# 1270                                     0
# 1271                                     7
#
#       Grade 4 Math 4s - Asian or Pacific Islander  Grade 4 Math 4s - White  \
# 1267                                            0                        0
# 1268                                            0                        0
# 1269                                            0                        0
# 1270                                            0                        0
# 1271                                            0                        0
#
#       Grade 4 Math 4s - Multiracial  \
# 1267                              0
# 1268                              0
# 1269                              0
# 1270                              0
# 1271                              0
#
#       Grade 4 Math 4s - Limited English Proficient  \
# 1267                                             0
# 1268                                             0
# 1269                                             0
# 1270                                             0
# 1271                                             0
#
#       Grade 4 Math 4s - Economically Disadvantaged  \
# 1267                                             0
# 1268                                             9
# 1269                                             0
# 1270                                            14
# 1271                                             9
#
#       Grade 5 ELA - All Students Tested  Grade 5 ELA 4s - All Students  \
# 1267                                 51                              2
# 1268                                 73                              1
# 1269                                 35                              5
# 1270                                 66                              3
# 1271                                 44                              3
#
#       Grade 5 ELA 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 5 ELA 4s - Black or African American  \
# 1267                                           0
# 1268                                           1
# 1269                                           4
# 1270                                           3
# 1271                                           0
#
#       Grade 5 ELA 4s - Hispanic or Latino  \
# 1267                                    2
# 1268                                    0
# 1269                                    1
# 1270                                    0
# 1271                                    0
#
#       Grade 5 ELA 4s - Asian or Pacific Islander  Grade 5 ELA 4s - White  \
# 1267                                           0                       0
# 1268                                           0                       0
# 1269                                           0                       0
# 1270                                           0                       0
# 1271                                           0                       0
#
#       Grade 5 ELA 4s - Multiracial  \
# 1267                             0
# 1268                             0
# 1269                             0
# 1270                             0
# 1271                             0
#
#       Grade 5 ELA 4s - Limited English Proficient  \
# 1267                                            0
# 1268                                            0
# 1269                                            0
# 1270                                            0
# 1271                                            0
#
#       Grade 5 ELA 4s - Economically Disadvantaged  \
# 1267                                            0
# 1268                                            1
# 1269                                            3
# 1270                                            1
# 1271                                            2
#
#       Grade 5 Math - All Students Tested  Grade 5 Math 4s - All Students  \
# 1267                                  51                               4
# 1268                                  73                               0
# 1269                                  35                              14
# 1270                                  66                              16
# 1271                                  44                               6
#
#       Grade 5 Math 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 5 Math 4s - Black or African American  \
# 1267                                            0
# 1268                                            0
# 1269                                            9
# 1270                                           15
# 1271                                            0
#
#       Grade 5 Math 4s - Hispanic or Latino  \
# 1267                                     2
# 1268                                     0
# 1269                                     5
# 1270                                     0
# 1271                                     2
#
#       Grade 5 Math 4s - Asian or Pacific Islander  Grade 5 Math 4s - White  \
# 1267                                            0                        0
# 1268                                            0                        0
# 1269                                            0                        0
# 1270                                            0                        0
# 1271                                            0                        0
#
#       Grade 5 Math 4s - Multiracial  \
# 1267                              0
# 1268                              0
# 1269                              0
# 1270                              0
# 1271                              0
#
#       Grade 5 Math 4s - Limited English Proficient  \
# 1267                                             0
# 1268                                             0
# 1269                                             0
# 1270                                             0
# 1271                                             0
#
#       Grade 5 Math 4s - Economically Disadvantaged  \
# 1267                                             0
# 1268                                             0
# 1269                                            11
# 1270                                            12
# 1271                                             4
#
#       Grade 6 ELA - All Students Tested  Grade 6 ELA 4s - All Students  \
# 1267                                 50                              3
# 1268                                 67                              3
# 1269                                 32                              5
# 1270                                  0                              0
# 1271                                  0                              0
#
#       Grade 6 ELA 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 6 ELA 4s - Black or African American  \
# 1267                                           1
# 1268                                           2
# 1269                                           2
# 1270                                           0
# 1271                                           0
#
#       Grade 6 ELA 4s - Hispanic or Latino  \
# 1267                                    2
# 1268                                    0
# 1269                                    3
# 1270                                    0
# 1271                                    0
#
#       Grade 6 ELA 4s - Asian or Pacific Islander  Grade 6 ELA 4s - White  \
# 1267                                           0                       0
# 1268                                           0                       0
# 1269                                           0                       0
# 1270                                           0                       0
# 1271                                           0                       0
#
#       Grade 6 ELA 4s - Multiracial  \
# 1267                             0
# 1268                             0
# 1269                             0
# 1270                             0
# 1271                             0
#
#       Grade 6 ELA 4s - Limited English Proficient  \
# 1267                                            0
# 1268                                            0
# 1269                                            0
# 1270                                            0
# 1271                                            0
#
#       Grade 6 ELA 4s - Economically Disadvantaged  \
# 1267                                            2
# 1268                                            2
# 1269                                            0
# 1270                                            0
# 1271                                            0
#
#       Grade 6 Math - All Students Tested  Grade 6 Math 4s - All Students  \
# 1267                                  50                              20
# 1268                                  67                              15
# 1269                                  32                               7
# 1270                                   0                               0
# 1271                                   0                               0
#
#       Grade 6 Math 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 6 Math 4s - Black or African American  \
# 1267                                            7
# 1268                                           12
# 1269                                            2
# 1270                                            0
# 1271                                            0
#
#       Grade 6 Math 4s - Hispanic or Latino  \
# 1267                                    13
# 1268                                     0
# 1269                                     5
# 1270                                     0
# 1271                                     0
#
#       Grade 6 Math 4s - Asian or Pacific Islander  Grade 6 Math 4s - White  \
# 1267                                            0                        0
# 1268                                            0                        0
# 1269                                            0                        0
# 1270                                            0                        0
# 1271                                            0                        0
#
#       Grade 6 Math 4s - Multiracial  \
# 1267                              0
# 1268                              0
# 1269                              0
# 1270                              0
# 1271                              0
#
#       Grade 6 Math 4s - Limited English Proficient  \
# 1267                                             0
# 1268                                             0
# 1269                                             0
# 1270                                             0
# 1271                                             0
#
#       Grade 6 Math 4s - Economically Disadvantaged  \
# 1267                                            14
# 1268                                             8
# 1269                                             0
# 1270                                             0
# 1271                                             0
#
#       Grade 7 ELA - All Students Tested  Grade 7 ELA 4s - All Students  \
# 1267                                 50                              1
# 1268                                 64                              2
# 1269                                 34                              2
# 1270                                  0                              0
# 1271                                  0                              0
#
#       Grade 7 ELA 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 7 ELA 4s - Black or African American  \
# 1267                                           0
# 1268                                           2
# 1269                                           1
# 1270                                           0
# 1271                                           0
#
#       Grade 7 ELA 4s - Hispanic or Latino  \
# 1267                                    1
# 1268                                    0
# 1269                                    0
# 1270                                    0
# 1271                                    0
#
#       Grade 7 ELA 4s - Asian or Pacific Islander  Grade 7 ELA 4s - White  \
# 1267                                           0                       0
# 1268                                           0                       0
# 1269                                           0                       0
# 1270                                           0                       0
# 1271                                           0                       0
#
#       Grade 7 ELA 4s - Multiracial  \
# 1267                             0
# 1268                             0
# 1269                             0
# 1270                             0
# 1271                             0
#
#       Grade 7 ELA 4s - Limited English Proficient  \
# 1267                                            0
# 1268                                            0
# 1269                                            0
# 1270                                            0
# 1271                                            0
#
#       Grade 7 ELA 4s - Economically Disadvantaged  \
# 1267                                            0
# 1268                                            2
# 1269                                            1
# 1270                                            0
# 1271                                            0
#
#       Grade 7 Math - All Students Tested  Grade 7 Math 4s - All Students  \
# 1267                                  50                               0
# 1268                                  64                               7
# 1269                                  34                               6
# 1270                                   0                               0
# 1271                                   0                               0
#
#       Grade 7 Math 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 7 Math 4s - Black or African American  \
# 1267                                            0
# 1268                                            6
# 1269                                            2
# 1270                                            0
# 1271                                            0
#
#       Grade 7 Math 4s - Hispanic or Latino  \
# 1267                                     0
# 1268                                     0
# 1269                                     0
# 1270                                     0
# 1271                                     0
#
#       Grade 7 Math 4s - Asian or Pacific Islander  Grade 7 Math 4s - White  \
# 1267                                            0                        0
# 1268                                            0                        0
# 1269                                            0                        0
# 1270                                            0                        0
# 1271                                            0                        0
#
#       Grade 7 Math 4s - Multiracial  \
# 1267                              0
# 1268                              0
# 1269                              0
# 1270                              0
# 1271                              0
#
#       Grade 7 Math 4s - Limited English Proficient  \
# 1267                                             0
# 1268                                             0
# 1269                                             0
# 1270                                             0
# 1271                                             0
#
#       Grade 7 Math 4s - Economically Disadvantaged  \
# 1267                                             0
# 1268                                             3
# 1269                                             3
# 1270                                             0
# 1271                                             0
#
#       Grade 8 ELA - All Students Tested  Grade 8 ELA 4s - All Students  \
# 1267                                 46                              6
# 1268                                 58                              3
# 1269                                 31                              6
# 1270                                  0                              0
# 1271                                  0                              0
#
#       Grade 8 ELA 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 8 ELA 4s - Black or African American  \
# 1267                                           2
# 1268                                           2
# 1269                                           3
# 1270                                           0
# 1271                                           0
#
#       Grade 8 ELA 4s - Hispanic or Latino  \
# 1267                                    4
# 1268                                    1
# 1269                                    3
# 1270                                    0
# 1271                                    0
#
#       Grade 8 ELA 4s - Asian or Pacific Islander  Grade 8 ELA 4s - White  \
# 1267                                           0                       0
# 1268                                           0                       0
# 1269                                           0                       0
# 1270                                           0                       0
# 1271                                           0                       0
#
#       Grade 8 ELA 4s - Multiracial  \
# 1267                             0
# 1268                             0
# 1269                             0
# 1270                             0
# 1271                             0
#
#       Grade 8 ELA 4s - Limited English Proficient  \
# 1267                                            0
# 1268                                            0
# 1269                                            0
# 1270                                            0
# 1271                                            0
#
#       Grade 8 ELA 4s - Economically Disadvantaged  \
# 1267                                            5
# 1268                                            2
# 1269                                            4
# 1270                                            0
# 1271                                            0
#
#       Grade 8 Math - All Students Tested  Grade 8 Math 4s - All Students  \
# 1267                                  47                               1
# 1268                                  58                               9
# 1269                                  31                               7
# 1270                                   0                               0
# 1271                                   0                               0
#
#       Grade 8 Math 4s - American Indian or Alaska Native  \
# 1267                                                  0
# 1268                                                  0
# 1269                                                  0
# 1270                                                  0
# 1271                                                  0
#
#       Grade 8 Math 4s - Black or African American  \
# 1267                                            1
# 1268                                            8
# 1269                                            3
# 1270                                            0
# 1271                                            0
#
#       Grade 8 Math 4s - Hispanic or Latino  \
# 1267                                     0
# 1268                                     1
# 1269                                     4
# 1270                                     0
# 1271                                     0
#
#       Grade 8 Math 4s - Asian or Pacific Islander  Grade 8 Math 4s - White  \
# 1267                                            0                        0
# 1268                                            0                        0
# 1269                                            0                        0
# 1270                                            0                        0
# 1271                                            0                        0
#
#       Grade 8 Math 4s - Multiracial  \
# 1267                              0
# 1268                              0
# 1269                              0
# 1270                              0
# 1271                              0
#
#       Grade 8 Math 4s - Limited English Proficient  \
# 1267                                             0
# 1268                                             0
# 1269                                             0
# 1270                                             0
# 1271                                             0
#
#       Grade 8 Math 4s - Economically Disadvantaged
# 1267                                             1
# 1268                                             5
# 1269                                             5
# 1270                                             0
# 1271                                             0

# %%
df.describe().T
# Out:
#                                                      count          mean  \
# SED Code                                            1272.0  3.286698e+11
# District                                            1272.0  1.613522e+01
# Latitude                                            1272.0  4.073454e+01
# Longitude                                           1272.0 -7.391835e+01
# Zip                                                 1272.0  1.081572e+04
# Economic Need Index                                 1247.0  6.722807e-01
# Average ELA Proficiency                             1217.0  2.534215e+00
# Average Math Proficiency                            1217.0  2.668956e+00
# Grade 3 ELA - All Students Tested                   1272.0  6.056918e+01
# Grade 3 ELA 4s - All Students                       1272.0  4.952830e+00
# Grade 3 ELA 4s - American Indian or Alaska Native   1272.0  9.433962e-03
# Grade 3 ELA 4s - Black or African American          1272.0  7.138365e-01
# Grade 3 ELA 4s - Hispanic or Latino                 1272.0  8.286164e-01
# Grade 3 ELA 4s - Asian or Pacific Islander          1272.0  1.347484e+00
# Grade 3 ELA 4s - White                              1272.0  1.370283e+00
# Grade 3 ELA 4s - Multiracial                        1272.0  3.930818e-02
# Grade 3 ELA 4s - Limited English Proficient         1272.0  2.437107e-02
# Grade 3 ELA 4s - Economically Disadvantaged         1272.0  1.982704e+00
# Grade 3 Math - All Students tested                  1272.0  6.165173e+01
# Grade 3 Math 4s - All Students                      1272.0  1.387814e+01
# Grade 3 Math 4s - American Indian or Alaska Native  1272.0  2.751572e-02
# Grade 3 Math 4s - Black or African American         1272.0  2.255503e+00
# Grade 3 Math 4s - Hispanic or Latino                1272.0  2.815252e+00
# Grade 3 Math 4s - Asian or Pacific Islander         1272.0  4.025943e+00
# Grade 3 Math 4s - White                             1272.0  3.010220e+00
# Grade 3 Math 4s - Multiracial                       1272.0  6.603774e-02
# Grade 3 Math 4s - Limited English Proficient        1272.0  5.306604e-01
# Grade 3 Math 4s - Economically Disadvantaged        1272.0  6.677673e+00
# Grade 4 ELA - All Students Tested                   1272.0  5.800786e+01
# Grade 4 ELA 4s - All Students                       1272.0  9.904088e+00
# ...                                                    ...           ...
# Grade 7 Math - All Students Tested                  1272.0  5.428695e+01
# Grade 7 Math 4s - All Students                      1272.0  8.559748e+00
# Grade 7 Math 4s - American Indian or Alaska Native  1272.0  1.886792e-02
# Grade 7 Math 4s - Black or African American         1272.0  7.476415e-01
# Grade 7 Math 4s - Hispanic or Latino                1272.0  1.360063e+00
# Grade 7 Math 4s - Asian or Pacific Islander         1272.0  3.366352e+00
# Grade 7 Math 4s - White                             1272.0  2.316824e+00
# Grade 7 Math 4s - Multiracial                       1272.0  3.380503e-02
# Grade 7 Math 4s - Limited English Proficient        1272.0  1.242138e-01
# Grade 7 Math 4s - Economically Disadvantaged        1272.0  4.551887e+00
# Grade 8 ELA - All Students Tested                   1272.0  5.216274e+01
# Grade 8 ELA 4s - All Students                       1272.0  7.322327e+00
# Grade 8 ELA 4s - American Indian or Alaska Native   1272.0  1.336478e-02
# Grade 8 ELA 4s - Black or African American          1272.0  9.166667e-01
# Grade 8 ELA 4s - Hispanic or Latino                 1272.0  1.520440e+00
# Grade 8 ELA 4s - Asian or Pacific Islander          1272.0  2.255503e+00
# Grade 8 ELA 4s - White                              1272.0  1.931604e+00
# Grade 8 ELA 4s - Multiracial                        1272.0  1.572327e-02
# Grade 8 ELA 4s - Limited English Proficient         1272.0  1.572327e-03
# Grade 8 ELA 4s - Economically Disadvantaged         1272.0  3.914308e+00
# Grade 8 Math - All Students Tested                  1272.0  4.384119e+01
# Grade 8 Math 4s - All Students                      1272.0  4.911950e+00
# Grade 8 Math 4s - American Indian or Alaska Native  1272.0  3.144654e-03
# Grade 8 Math 4s - Black or African American         1272.0  6.100629e-01
# Grade 8 Math 4s - Hispanic or Latino                1272.0  9.473270e-01
# Grade 8 Math 4s - Asian or Pacific Islander         1272.0  1.984277e+00
# Grade 8 Math 4s - White                             1272.0  9.709119e-01
# Grade 8 Math 4s - Multiracial                       1272.0  2.358491e-03
# Grade 8 Math 4s - Limited English Proficient        1272.0  1.595912e-01
# Grade 8 Math 4s - Economically Disadvantaged        1272.0  2.992138e+00
#
#                                                              std  \
# SED Code                                            1.222022e+10
# District                                            9.245270e+00
# Latitude                                            8.660234e-02
# Longitude                                           8.057649e-02
# Zip                                                 5.295889e+02
# Economic Need Index                                 2.109594e-01
# Average ELA Proficiency                             3.635894e-01
# Average Math Proficiency                            4.704699e-01
# Grade 3 ELA - All Students Tested                   5.787250e+01
# Grade 3 ELA 4s - All Students                       8.300568e+00
# Grade 3 ELA 4s - American Indian or Alaska Native   1.481244e-01
# Grade 3 ELA 4s - Black or African American          2.272858e+00
# Grade 3 ELA 4s - Hispanic or Latino                 1.839046e+00
# Grade 3 ELA 4s - Asian or Pacific Islander          4.113688e+00
# Grade 3 ELA 4s - White                              4.096073e+00
# Grade 3 ELA 4s - Multiracial                        3.526170e-01
# Grade 3 ELA 4s - Limited English Proficient         1.823108e-01
# Grade 3 ELA 4s - Economically Disadvantaged         3.738251e+00
# Grade 3 Math - All Students tested                  5.921196e+01
# Grade 3 Math 4s - All Students                      2.000378e+01
# Grade 3 Math 4s - American Indian or Alaska Native  2.661568e-01
# Grade 3 Math 4s - Black or African American         7.041183e+00
# Grade 3 Math 4s - Hispanic or Latino                5.408097e+00
# Grade 3 Math 4s - Asian or Pacific Islander         1.184406e+01
# Grade 3 Math 4s - White                             8.294485e+00
# Grade 3 Math 4s - Multiracial                       5.570892e-01
# Grade 3 Math 4s - Limited English Proficient        2.181534e+00
# Grade 3 Math 4s - Economically Disadvantaged        1.126136e+01
# Grade 4 ELA - All Students Tested                   5.718632e+01
# Grade 4 ELA 4s - All Students                       1.516425e+01
# ...                                                          ...
# Grade 7 Math - All Students Tested                  9.710736e+01
# Grade 7 Math 4s - All Students                      2.806547e+01
# Grade 7 Math 4s - American Indian or Alaska Native  2.935809e-01
# Grade 7 Math 4s - Black or African American         3.088263e+00
# Grade 7 Math 4s - Hispanic or Latino                4.380334e+00
# Grade 7 Math 4s - Asian or Pacific Islander         1.569395e+01
# Grade 7 Math 4s - White                             1.211898e+01
# Grade 7 Math 4s - Multiracial                       4.950950e-01
# Grade 7 Math 4s - Limited English Proficient        1.009933e+00
# Grade 7 Math 4s - Economically Disadvantaged        1.533899e+01
# Grade 8 ELA - All Students Tested                   9.499270e+01
# Grade 8 ELA 4s - All Students                       2.150125e+01
# Grade 8 ELA 4s - American Indian or Alaska Native   2.186663e-01
# Grade 8 ELA 4s - Black or African American          3.308569e+00
# Grade 8 ELA 4s - Hispanic or Latino                 4.241108e+00
# Grade 8 ELA 4s - Asian or Pacific Islander          1.111658e+01
# Grade 8 ELA 4s - White                              9.205968e+00
# Grade 8 ELA 4s - Multiracial                        3.243168e-01
# Grade 8 ELA 4s - Limited English Proficient         3.963698e-02
# Grade 8 ELA 4s - Economically Disadvantaged         1.127636e+01
# Grade 8 Math - All Students Tested                  8.287878e+01
# Grade 8 Math 4s - All Students                      2.079237e+01
# Grade 8 Math 4s - American Indian or Alaska Native  6.863524e-02
# Grade 8 Math 4s - Black or African American         3.966083e+00
# Grade 8 Math 4s - Hispanic or Latino                4.056007e+00
# Grade 8 Math 4s - Asian or Pacific Islander         1.284133e+01
# Grade 8 Math 4s - White                             6.880223e+00
# Grade 8 Math 4s - Multiracial                       8.411582e-02
# Grade 8 Math 4s - Limited English Proficient        1.321195e+00
# Grade 8 Math 4s - Economically Disadvantaged        1.269412e+01
#
#                                                              min  \
# SED Code                                            3.075000e+11
# District                                            1.000000e+00
# Latitude                                            4.050780e+01
# Longitude                                          -7.424402e+01
# Zip                                                 1.000100e+04
# Economic Need Index                                 4.900000e-02
# Average ELA Proficiency                             1.810000e+00
# Average Math Proficiency                            1.830000e+00
# Grade 3 ELA - All Students Tested                   0.000000e+00
# Grade 3 ELA 4s - All Students                       0.000000e+00
# Grade 3 ELA 4s - American Indian or Alaska Native   0.000000e+00
# Grade 3 ELA 4s - Black or African American          0.000000e+00
# Grade 3 ELA 4s - Hispanic or Latino                 0.000000e+00
# Grade 3 ELA 4s - Asian or Pacific Islander          0.000000e+00
# Grade 3 ELA 4s - White                              0.000000e+00
# Grade 3 ELA 4s - Multiracial                        0.000000e+00
# Grade 3 ELA 4s - Limited English Proficient         0.000000e+00
# Grade 3 ELA 4s - Economically Disadvantaged         0.000000e+00
# Grade 3 Math - All Students tested                  0.000000e+00
# Grade 3 Math 4s - All Students                      0.000000e+00
# Grade 3 Math 4s - American Indian or Alaska Native  0.000000e+00
# Grade 3 Math 4s - Black or African American         0.000000e+00
# Grade 3 Math 4s - Hispanic or Latino                0.000000e+00
# Grade 3 Math 4s - Asian or Pacific Islander         0.000000e+00
# Grade 3 Math 4s - White                             0.000000e+00
# Grade 3 Math 4s - Multiracial                       0.000000e+00
# Grade 3 Math 4s - Limited English Proficient        0.000000e+00
# Grade 3 Math 4s - Economically Disadvantaged        0.000000e+00
# Grade 4 ELA - All Students Tested                   0.000000e+00
# Grade 4 ELA 4s - All Students                       0.000000e+00
# ...                                                          ...
# Grade 7 Math - All Students Tested                  0.000000e+00
# Grade 7 Math 4s - All Students                      0.000000e+00
# Grade 7 Math 4s - American Indian or Alaska Native  0.000000e+00
# Grade 7 Math 4s - Black or African American         0.000000e+00
# Grade 7 Math 4s - Hispanic or Latino                0.000000e+00
# Grade 7 Math 4s - Asian or Pacific Islander         0.000000e+00
# Grade 7 Math 4s - White                             0.000000e+00
# Grade 7 Math 4s - Multiracial                       0.000000e+00
# Grade 7 Math 4s - Limited English Proficient        0.000000e+00
# Grade 7 Math 4s - Economically Disadvantaged        0.000000e+00
# Grade 8 ELA - All Students Tested                   0.000000e+00
# Grade 8 ELA 4s - All Students                       0.000000e+00
# Grade 8 ELA 4s - American Indian or Alaska Native   0.000000e+00
# Grade 8 ELA 4s - Black or African American          0.000000e+00
# Grade 8 ELA 4s - Hispanic or Latino                 0.000000e+00
# Grade 8 ELA 4s - Asian or Pacific Islander          0.000000e+00
# Grade 8 ELA 4s - White                              0.000000e+00
# Grade 8 ELA 4s - Multiracial                        0.000000e+00
# Grade 8 ELA 4s - Limited English Proficient         0.000000e+00
# Grade 8 ELA 4s - Economically Disadvantaged         0.000000e+00
# Grade 8 Math - All Students Tested                  0.000000e+00
# Grade 8 Math 4s - All Students                      0.000000e+00
# Grade 8 Math 4s - American Indian or Alaska Native  0.000000e+00
# Grade 8 Math 4s - Black or African American         0.000000e+00
# Grade 8 Math 4s - Hispanic or Latino                0.000000e+00
# Grade 8 Math 4s - Asian or Pacific Islander         0.000000e+00
# Grade 8 Math 4s - White                             0.000000e+00
# Grade 8 Math 4s - Multiracial                       0.000000e+00
# Grade 8 Math 4s - Limited English Proficient        0.000000e+00
# Grade 8 Math 4s - Economically Disadvantaged        0.000000e+00
#
#                                                              25%  \
# SED Code                                            3.208752e+11
# District                                            9.000000e+00
# Latitude                                            4.066950e+01
# Longitude                                          -7.395706e+01
# Zip                                                 1.045200e+04
# Economic Need Index                                 5.500000e-01
# Average ELA Proficiency                             2.250000e+00
# Average Math Proficiency                            2.300000e+00
# Grade 3 ELA - All Students Tested                   0.000000e+00
# Grade 3 ELA 4s - All Students                       0.000000e+00
# Grade 3 ELA 4s - American Indian or Alaska Native   0.000000e+00
# Grade 3 ELA 4s - Black or African American          0.000000e+00
# Grade 3 ELA 4s - Hispanic or Latino                 0.000000e+00
# Grade 3 ELA 4s - Asian or Pacific Islander          0.000000e+00
# Grade 3 ELA 4s - White                              0.000000e+00
# Grade 3 ELA 4s - Multiracial                        0.000000e+00
# Grade 3 ELA 4s - Limited English Proficient         0.000000e+00
# Grade 3 ELA 4s - Economically Disadvantaged         0.000000e+00
# Grade 3 Math - All Students tested                  0.000000e+00
# Grade 3 Math 4s - All Students                      0.000000e+00
# Grade 3 Math 4s - American Indian or Alaska Native  0.000000e+00
# Grade 3 Math 4s - Black or African American         0.000000e+00
# Grade 3 Math 4s - Hispanic or Latino                0.000000e+00
# Grade 3 Math 4s - Asian or Pacific Islander         0.000000e+00
# Grade 3 Math 4s - White                             0.000000e+00
# Grade 3 Math 4s - Multiracial                       0.000000e+00
# Grade 3 Math 4s - Limited English Proficient        0.000000e+00
# Grade 3 Math 4s - Economically Disadvantaged        0.000000e+00
# Grade 4 ELA - All Students Tested                   0.000000e+00
# Grade 4 ELA 4s - All Students                       0.000000e+00
# ...                                                          ...
# Grade 7 Math - All Students Tested                  0.000000e+00
# Grade 7 Math 4s - All Students                      0.000000e+00
# Grade 7 Math 4s - American Indian or Alaska Native  0.000000e+00
# Grade 7 Math 4s - Black or African American         0.000000e+00
# Grade 7 Math 4s - Hispanic or Latino                0.000000e+00
# Grade 7 Math 4s - Asian or Pacific Islander         0.000000e+00
# Grade 7 Math 4s - White                             0.000000e+00
# Grade 7 Math 4s - Multiracial                       0.000000e+00
# Grade 7 Math 4s - Limited English Proficient        0.000000e+00
# Grade 7 Math 4s - Economically Disadvantaged        0.000000e+00
# Grade 8 ELA - All Students Tested                   0.000000e+00
# Grade 8 ELA 4s - All Students                       0.000000e+00
# Grade 8 ELA 4s - American Indian or Alaska Native   0.000000e+00
# Grade 8 ELA 4s - Black or African American          0.000000e+00
# Grade 8 ELA 4s - Hispanic or Latino                 0.000000e+00
# Grade 8 ELA 4s - Asian or Pacific Islander          0.000000e+00
# Grade 8 ELA 4s - White                              0.000000e+00
# Grade 8 ELA 4s - Multiracial                        0.000000e+00
# Grade 8 ELA 4s - Limited English Proficient         0.000000e+00
# Grade 8 ELA 4s - Economically Disadvantaged         0.000000e+00
# Grade 8 Math - All Students Tested                  0.000000e+00
# Grade 8 Math 4s - All Students                      0.000000e+00
# Grade 8 Math 4s - American Indian or Alaska Native  0.000000e+00
# Grade 8 Math 4s - Black or African American         0.000000e+00
# Grade 8 Math 4s - Hispanic or Latino                0.000000e+00
# Grade 8 Math 4s - Asian or Pacific Islander         0.000000e+00
# Grade 8 Math 4s - White                             0.000000e+00
# Grade 8 Math 4s - Multiracial                       0.000000e+00
# Grade 8 Math 4s - Limited English Proficient        0.000000e+00
# Grade 8 Math 4s - Economically Disadvantaged        0.000000e+00
#
#                                                              50%  \
# SED Code                                            3.315004e+11
# District                                            1.500000e+01
# Latitude                                            4.072299e+01
# Longitude                                          -7.392057e+01
# Zip                                                 1.120300e+04
# Economic Need Index                                 7.310000e-01
# Average ELA Proficiency                             2.450000e+00
# Average Math Proficiency                            2.580000e+00
# Grade 3 ELA - All Students Tested                   5.400000e+01
# Grade 3 ELA 4s - All Students                       1.000000e+00
# Grade 3 ELA 4s - American Indian or Alaska Native   0.000000e+00
# Grade 3 ELA 4s - Black or African American          0.000000e+00
# Grade 3 ELA 4s - Hispanic or Latino                 0.000000e+00
# Grade 3 ELA 4s - Asian or Pacific Islander          0.000000e+00
# Grade 3 ELA 4s - White                              0.000000e+00
# Grade 3 ELA 4s - Multiracial                        0.000000e+00
# Grade 3 ELA 4s - Limited English Proficient         0.000000e+00
# Grade 3 ELA 4s - Economically Disadvantaged         0.000000e+00
# Grade 3 Math - All Students tested                  5.500000e+01
# Grade 3 Math 4s - All Students                      5.000000e+00
# Grade 3 Math 4s - American Indian or Alaska Native  0.000000e+00
# Grade 3 Math 4s - Black or African American         0.000000e+00
# Grade 3 Math 4s - Hispanic or Latino                0.000000e+00
# Grade 3 Math 4s - Asian or Pacific Islander         0.000000e+00
# Grade 3 Math 4s - White                             0.000000e+00
# Grade 3 Math 4s - Multiracial                       0.000000e+00
# Grade 3 Math 4s - Limited English Proficient        0.000000e+00
# Grade 3 Math 4s - Economically Disadvantaged        1.000000e+00
# Grade 4 ELA - All Students Tested                   5.200000e+01
# Grade 4 ELA 4s - All Students                       3.000000e+00
# ...                                                          ...
# Grade 7 Math - All Students Tested                  0.000000e+00
# Grade 7 Math 4s - All Students                      0.000000e+00
# Grade 7 Math 4s - American Indian or Alaska Native  0.000000e+00
# Grade 7 Math 4s - Black or African American         0.000000e+00
# Grade 7 Math 4s - Hispanic or Latino                0.000000e+00
# Grade 7 Math 4s - Asian or Pacific Islander         0.000000e+00
# Grade 7 Math 4s - White                             0.000000e+00
# Grade 7 Math 4s - Multiracial                       0.000000e+00
# Grade 7 Math 4s - Limited English Proficient        0.000000e+00
# Grade 7 Math 4s - Economically Disadvantaged        0.000000e+00
# Grade 8 ELA - All Students Tested                   0.000000e+00
# Grade 8 ELA 4s - All Students                       0.000000e+00
# Grade 8 ELA 4s - American Indian or Alaska Native   0.000000e+00
# Grade 8 ELA 4s - Black or African American          0.000000e+00
# Grade 8 ELA 4s - Hispanic or Latino                 0.000000e+00
# Grade 8 ELA 4s - Asian or Pacific Islander          0.000000e+00
# Grade 8 ELA 4s - White                              0.000000e+00
# Grade 8 ELA 4s - Multiracial                        0.000000e+00
# Grade 8 ELA 4s - Limited English Proficient         0.000000e+00
# Grade 8 ELA 4s - Economically Disadvantaged         0.000000e+00
# Grade 8 Math - All Students Tested                  0.000000e+00
# Grade 8 Math 4s - All Students                      0.000000e+00
# Grade 8 Math 4s - American Indian or Alaska Native  0.000000e+00
# Grade 8 Math 4s - Black or African American         0.000000e+00
# Grade 8 Math 4s - Hispanic or Latino                0.000000e+00
# Grade 8 Math 4s - Asian or Pacific Islander         0.000000e+00
# Grade 8 Math 4s - White                             0.000000e+00
# Grade 8 Math 4s - Multiracial                       0.000000e+00
# Grade 8 Math 4s - Limited English Proficient        0.000000e+00
# Grade 8 Math 4s - Economically Disadvantaged        0.000000e+00
#
#                                                              75%           max
# SED Code                                            3.424000e+11  3.531009e+11
# District                                            2.400000e+01  3.200000e+01
# Latitude                                            4.081563e+01  4.090346e+01
# Longitude                                          -7.387926e+01 -7.370892e+01
# Zip                                                 1.123200e+04  1.169400e+04
# Economic Need Index                                 8.410000e-01  9.570000e-01
# Average ELA Proficiency                             2.760000e+00  3.930000e+00
# Average Math Proficiency                            2.980000e+00  4.200000e+00
# Grade 3 ELA - All Students Tested                   9.400000e+01  3.560000e+02
# Grade 3 ELA 4s - All Students                       7.000000e+00  5.500000e+01
# Grade 3 ELA 4s - American Indian or Alaska Native   0.000000e+00  3.000000e+00
# Grade 3 ELA 4s - Black or African American          0.000000e+00  2.400000e+01
# Grade 3 ELA 4s - Hispanic or Latino                 1.000000e+00  2.000000e+01
# Grade 3 ELA 4s - Asian or Pacific Islander          0.000000e+00  3.900000e+01
# Grade 3 ELA 4s - White                              0.000000e+00  3.700000e+01
# Grade 3 ELA 4s - Multiracial                        0.000000e+00  5.000000e+00
# Grade 3 ELA 4s - Limited English Proficient         0.000000e+00  3.000000e+00
# Grade 3 ELA 4s - Economically Disadvantaged         2.000000e+00  2.900000e+01
# Grade 3 Math - All Students tested                  9.600000e+01  3.650000e+02
# Grade 3 Math 4s - All Students                      2.000000e+01  1.300000e+02
# Grade 3 Math 4s - American Indian or Alaska Native  0.000000e+00  4.000000e+00
# Grade 3 Math 4s - Black or African American         1.000000e+00  6.700000e+01
# Grade 3 Math 4s - Hispanic or Latino                3.000000e+00  4.100000e+01
# Grade 3 Math 4s - Asian or Pacific Islander         0.000000e+00  1.100000e+02
# Grade 3 Math 4s - White                             0.000000e+00  6.500000e+01
# Grade 3 Math 4s - Multiracial                       0.000000e+00  8.000000e+00
# Grade 3 Math 4s - Limited English Proficient        0.000000e+00  3.900000e+01
# Grade 3 Math 4s - Economically Disadvantaged        9.000000e+00  9.800000e+01
# Grade 4 ELA - All Students Tested                   9.200000e+01  3.300000e+02
# Grade 4 ELA 4s - All Students                       1.300000e+01  1.010000e+02
# ...                                                          ...           ...
# Grade 7 Math - All Students Tested                  7.800000e+01  7.150000e+02
# Grade 7 Math 4s - All Students                      3.000000e+00  3.040000e+02
# Grade 7 Math 4s - American Indian or Alaska Native  0.000000e+00  7.000000e+00
# Grade 7 Math 4s - Black or African American         0.000000e+00  4.500000e+01
# Grade 7 Math 4s - Hispanic or Latino                0.000000e+00  5.100000e+01
# Grade 7 Math 4s - Asian or Pacific Islander         0.000000e+00  2.060000e+02
# Grade 7 Math 4s - White                             0.000000e+00  1.760000e+02
# Grade 7 Math 4s - Multiracial                       0.000000e+00  1.100000e+01
# Grade 7 Math 4s - Limited English Proficient        0.000000e+00  2.800000e+01
# Grade 7 Math 4s - Economically Disadvantaged        1.000000e+00  1.660000e+02
# Grade 8 ELA - All Students Tested                   7.425000e+01  7.430000e+02
# Grade 8 ELA 4s - All Students                       4.000000e+00  2.610000e+02
# Grade 8 ELA 4s - American Indian or Alaska Native   0.000000e+00  5.000000e+00
# Grade 8 ELA 4s - Black or African American          0.000000e+00  5.900000e+01
# Grade 8 ELA 4s - Hispanic or Latino                 1.000000e+00  6.200000e+01
# Grade 8 ELA 4s - Asian or Pacific Islander          0.000000e+00  2.030000e+02
# Grade 8 ELA 4s - White                              0.000000e+00  1.160000e+02
# Grade 8 ELA 4s - Multiracial                        0.000000e+00  9.000000e+00
# Grade 8 ELA 4s - Limited English Proficient         0.000000e+00  1.000000e+00
# Grade 8 ELA 4s - Economically Disadvantaged         3.000000e+00  1.590000e+02
# Grade 8 Math - All Students Tested                  5.900000e+01  6.520000e+02
# Grade 8 Math 4s - All Students                      1.000000e+00  3.120000e+02
# Grade 8 Math 4s - American Indian or Alaska Native  0.000000e+00  2.000000e+00
# Grade 8 Math 4s - Black or African American         0.000000e+00  1.070000e+02
# Grade 8 Math 4s - Hispanic or Latino                0.000000e+00  7.100000e+01
# Grade 8 Math 4s - Asian or Pacific Islander         0.000000e+00  2.460000e+02
# Grade 8 Math 4s - White                             0.000000e+00  1.260000e+02
# Grade 8 Math 4s - Multiracial                       0.000000e+00  3.000000e+00
# Grade 8 Math 4s - Limited English Proficient        0.000000e+00  3.300000e+01
# Grade 8 Math 4s - Economically Disadvantaged        0.000000e+00  1.960000e+02
#
# [128 rows x 8 columns]

# %%
# There are 1272 schools in the data set
df.shape
# Out:
# (1272, 161)

# %%
for col in df.columns.values:
    if '%' in str(df[col][0]):
        print( col )
# Out:
# Percent ELL
# Percent Asian
# Percent Black
# Percent Hispanic
# Percent Black / Hispanic
# Percent White
# Student Attendance Rate
# Percent of Students Chronically Absent
# Rigorous Instruction %
# Collaborative Teachers %
# Supportive Environment %
# Effective School Leadership %
# Strong Family-Community Ties %
# Trust %

# %%
# Preprocess some data
# Create a function to convert the percentage to a fraction 
def p2f(x):
    return float(x.strip('%'))/100


df['Percent of Students Chronically Absent']=df['Percent of Students Chronically Absent'].astype(str).apply(p2f)
df['Rigorous Instruction %'] = df['Rigorous Instruction %'].astype(str).apply(p2f)
df['Collaborative Teachers %'] = df['Collaborative Teachers %'].astype(str).apply(p2f)
df['Supportive Environment %'] = df['Supportive Environment %'].astype(str).apply(p2f)
df['Effective School Leadership %'] = df['Effective School Leadership %'].astype(str).apply(p2f)
df['Strong Family-Community Ties %'] = df['Strong Family-Community Ties %'].astype(str).apply(p2f)
df['Trust %'] = df['Trust %'].astype(str).apply(p2f)
df['Student Attendance Rate'] = df['Student Attendance Rate'].astype(str).apply(p2f)

# %% [markdown]
# <a id='map_of_newyork'></a>
# # Map of New York
# ***

# %% [markdown]
# ### We can get futher info here https://en.wikipedia.org/wiki/New_York_City
#
#
# <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Map_of_New_York_Economic_Regions.svg/2000px-Map_of_New_York_Economic_Regions.svg.png'/>

# %% [markdown]
# # New York Map of Economic Need Index Distribution
# ***

# %% [markdown]
# **More Red** =  Schools with **Higher Economic Need**
#
# **More Blue**  = School with **Less Economic Need**
#
# ### Upper and Central New York Needs More Help
# Schools that are located in the **Upper and Central New York Area** have a **higher** economic need

# %%
df['School Income Estimate'][0]
# Out:
# '$31,141.72 '

# %% [markdown]
# #### Need to refine it

# %%
df['School Income Estimate'] = df['School Income Estimate'].str.replace(',', '')
df['School Income Estimate'] = df['School Income Estimate'].str.replace('$', '')
df['School Income Estimate'] = df['School Income Estimate'].str.replace(' ', '')
df['School Income Estimate'] = df['School Income Estimate'].astype(float)

df['School Income Estimate'][0]
# Out:
# 31141.72

# %%
df['School Income Estimate'] = df['School Income Estimate'].fillna(0)
df['Economic Need Index'] = df['Economic Need Index'].fillna(0)

# %%
# Static Version
df.plot(kind="scatter", x="Longitude", y="Latitude",
    s=df['School Income Estimate']/1210, c="Economic Need Index", cmap=plt.get_cmap("jet"),
        label='Schools', title='New York School Population Map',colorbar=True, alpha=0.4, figsize=(15,7))
plt.legend()
plt.show()

# %%
# !pip install plotly

# %%
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools
import plotly.plotly as py
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = [
    {
        'x': df["Longitude"],
        'y': df["Latitude"],
        'text': df["School Name"],
        'mode': 'markers',
        'marker': {
            'color': df["Economic Need Index"],
            'size': df["School Income Estimate"]/4500,
            'showscale': True,
            'colorscale':'Portland'
        }
    }
]

layout= go.Layout(
    title= 'New York School Population (Economic Need Index)',
    xaxis= dict(
        title= 'Longitude'
    ),
    yaxis=dict(
        title='Latitude'
    ))
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='scatter_hover_labels')
# Out:
# <div id="995adc2d-16ac-4385-9ec4-ab4e4baf2bac" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '995adc2d-16ac-4385-9ec4-ab4e4baf2bac',
#             [{"marker": {"colorscale": "Portland", "showscale": true, "color": [0.919, 0.6409999999999999, 0.7440000000000001, 0.86, 0.73, 0.858, 0.499, 0.833, 0.8490000000000001, 0.861, 0.5589999999999999, 0.917, 0.8320000000000001, 0.7909999999999999, 0.36200000000000004, 0.7709999999999999, 0.451, 0.43, 0.44799999999999995, 0.764, 0.61, 0.257, 0.597, 0.769, 0.858, 0.17600000000000002, 0.10099999999999999, 0.293, 0.43, 0.153, 0.066, 0.785, 0.626, 0.075, 0.069, 0.068, 0.522, 0.645, 0.10400000000000001, 0.307, 0.578, 0.728, 0.616, 0.8370000000000001, 0.196, 0.36700000000000005, 0.11, 0.36, 0.271, 0.07400000000000001, 0.365, 0.2, 0.293, 0.429, 0.065, 0.131, 0.23600000000000002, 0.049, 0.114, 0.313, 0.064, 0.308, 0.0, 0.812, 0.059000000000000004, 0.258, 0.33, 0.358, 0.406, 0.46799999999999997, 0.0, 0.765, 0.564, 0.613, 0.221, 0.221, 0.599, 0.85, 0.5, 0.099, 0.843, 0.883, 0.503, 0.7390000000000001, 0.217, 0.69, 0.758, 0.078, 0.875, 0.8490000000000001, 0.8859999999999999, 0.18100000000000002, 0.304, 0.802, 0.6609999999999999, 0.778, 0.73, 0.0, 0.233, 0.134, 0.7909999999999999, 0.767, 0.162, 0.253, 0.7859999999999999, 0.47700000000000004, 0.899, 0.435, 0.779, 0.915, 0.89, 0.885, 0.866, 0.772, 0.902, 0.833, 0.843, 0.903, 0.902, 0.7509999999999999, 0.8590000000000001, 0.8170000000000001, 0.708, 0.836, 0.917, 0.865, 0.85, 0.38299999999999995, 0.722, 0.8420000000000001, 0.46, 0.8959999999999999, 0.8390000000000001, 0.903, 0.897, 0.835, 0.805, 0.8540000000000001, 0.875, 0.747, 0.899, 0.875, 0.893, 0.898, 0.8740000000000001, 0.892, 0.8170000000000001, 0.852, 0.7829999999999999, 0.507, 0.708, 0.8809999999999999, 0.536, 0.732, 0.8440000000000001, 0.851, 0.841, 0.823, 0.9009999999999999, 0.8009999999999999, 0.8240000000000001, 0.856, 0.882, 0.8170000000000001, 0.857, 0.8490000000000001, 0.8690000000000001, 0.8340000000000001, 0.75, 0.721, 0.406, 0.872, 0.8290000000000001, 0.7859999999999999, 0.8, 0.84, 0.7240000000000001, 0.604, 0.708, 0.713, 0.429, 0.838, 0.861, 0.779, 0.8640000000000001, 0.8340000000000001, 0.85, 0.84, 0.878, 0.777, 0.7559999999999999, 0.615, 0.867, 0.915, 0.905, 0.914, 0.863, 0.8909999999999999, 0.9229999999999999, 0.878, 0.91, 0.924, 0.9570000000000001, 0.89, 0.912, 0.879, 0.9059999999999999, 0.9059999999999999, 0.899, 0.872, 0.866, 0.903, 0.9279999999999999, 0.9079999999999999, 0.882, 0.885, 0.897, 0.9229999999999999, 0.799, 0.882, 0.498, 0.779, 0.922, 0.8959999999999999, 0.7509999999999999, 0.511, 0.7609999999999999, 0.922, 0.667, 0.86, 0.489, 0.9129999999999999, 0.8, 0.8759999999999999, 0.821, 0.872, 0.812, 0.851, 0.875, 0.9109999999999999, 0.9129999999999999, 0.73, 0.853, 0.823, 0.9059999999999999, 0.38799999999999996, 0.915, 0.8909999999999999, 0.7809999999999999, 0.723, 0.56, 0.818, 0.7559999999999999, 0.8759999999999999, 0.802, 0.639, 0.7959999999999999, 0.903, 0.9229999999999999, 0.877, 0.922, 0.8340000000000001, 0.935, 0.919, 0.9390000000000001, 0.91, 0.89, 0.9159999999999999, 0.8909999999999999, 0.87, 0.8740000000000001, 0.91, 0.904, 0.9, 0.91, 0.852, 0.9279999999999999, 0.888, 0.9279999999999999, 0.9009999999999999, 0.865, 0.8390000000000001, 0.861, 0.929, 0.885, 0.705, 0.872, 0.882, 0.8220000000000001, 0.934, 0.9159999999999999, 0.9009999999999999, 0.929, 0.8809999999999999, 0.892, 0.8190000000000001, 0.8909999999999999, 0.862, 0.938, 0.9129999999999999, 0.92, 0.8859999999999999, 0.8009999999999999, 0.898, 0.8759999999999999, 0.86, 0.909, 0.8029999999999999, 0.833, 0.816, 0.8640000000000001, 0.746, 0.8, 0.9229999999999999, 0.852, 0.8059999999999999, 0.905, 0.22699999999999998, 0.925, 0.91, 0.752, 0.8859999999999999, 0.9059999999999999, 0.7140000000000001, 0.8959999999999999, 0.821, 0.934, 0.8270000000000001, 0.35700000000000004, 0.925, 0.878, 0.903, 0.862, 0.7859999999999999, 0.843, 0.418, 0.907, 0.887, 0.909, 0.8059999999999999, 0.903, 0.821, 0.851, 0.85, 0.88, 0.885, 0.9179999999999999, 0.8370000000000001, 0.9229999999999999, 0.91, 0.836, 0.8240000000000001, 0.8740000000000001, 0.868, 0.894, 0.909, 0.857,  ...

# %% [markdown]
# <a id='black_hispanic_geomap'></a>
# # New York Map of Black/Hispanic Percentage of Schools
# ***

# %%
df['Percent Asian'] = df['Percent Asian'].apply(p2f)
df['Percent Black'] = df['Percent Black'].apply(p2f)
df['Percent Hispanic'] = df['Percent Hispanic'].apply(p2f)
df['Percent White'] = df['Percent White'].apply(p2f)
df['Percent Black / Hispanic'] = df['Percent Black / Hispanic'].apply(p2f)

df['Percent Black / Hispanic'][0]
# Out:
# 0.92

# %% [markdown]
# ### Central New York contains most of the Schools with Blacks
# Majority of the **black** population are living in **Central New York**. If you compare this to the Hispanic Population, they are totally isolated from each other.

# %%
data = [
    {
        'x': df["Longitude"],
        'y': df["Latitude"],
        'text': df["School Name"],
        'mode': 'markers',
        'marker': {
            'color': df["Percent Black"],
            'size': df["School Income Estimate"]/4500,
            'showscale': True,
            'colorscale':'Portland'
        }
    }
]

layout= go.Layout(
    title= 'New York Black Student Ratio Of School',
    xaxis= dict(
        title= 'Longitude'
    ),
    yaxis=dict(
        title='Latitude'
    )
)
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='scatter_hover_labels')
# Out:
# <div id="dc75d637-0ede-470c-9e6d-e16892f36596" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'dc75d637-0ede-470c-9e6d-e16892f36596',
#             [{"marker": {"colorscale": "Portland", "showscale": true, "color": [0.32, 0.2, 0.08, 0.29, 0.2, 0.19, 0.1, 0.2, 0.13, 0.11, 0.04, 0.3, 0.26, 0.29, 0.09, 0.27, 0.1, 0.13, 0.13, 0.22, 0.21, 0.09, 0.16, 0.12, 0.04, 0.05, 0.02, 0.07, 0.12, 0.03, 0.02, 0.0, 0.12, 0.02, 0.0, 0.02, 0.08, 0.16, 0.03, 0.09, 0.0, 0.11, 0.01, 0.08, 0.05, 0.14, 0.04, 0.08, 0.11, 0.04, 0.1, 0.06, 0.16, 0.19, 0.01, 0.03, 0.06, 0.02, 0.04, 0.08, 0.01, 0.02, 0.03, 0.22, 0.03, 0.16, 0.23, 0.11, 0.19, 0.25, 0.02, 0.31, 0.09, 0.2, 0.05, 0.08, 0.23, 0.8, 0.13, 0.05, 0.25, 0.64, 0.16, 0.14, 0.06, 0.57, 0.36, 0.02, 0.61, 0.53, 0.65, 0.15, 0.14, 0.01, 0.32, 0.51, 0.45, 0.1, 0.11, 0.04, 0.53, 0.52, 0.08, 0.13, 0.68, 0.26, 0.3, 0.25, 0.45, 0.31, 0.45, 0.26, 0.13, 0.2, 0.26, 0.3, 0.28, 0.26, 0.11, 0.25, 0.07, 0.26, 0.36, 0.15, 0.41, 0.45, 0.4, 0.2, 0.25, 0.29, 0.29, 0.47, 0.45, 0.5, 0.61, 0.52, 0.43, 0.42, 0.52, 0.74, 0.55, 0.18, 0.64, 0.52, 0.62, 0.54, 0.59, 0.53, 0.79, 0.21, 0.71, 0.52, 0.39, 0.74, 0.08, 0.06, 0.04, 0.01, 0.12, 0.01, 0.04, 0.02, 0.01, 0.03, 0.01, 0.01, 0.02, 0.2, 0.03, 0.02, 0.03, 0.01, 0.07, 0.11, 0.03, 0.02, 0.09, 0.03, 0.05, 0.01, 0.03, 0.05, 0.03, 0.11, 0.05, 0.12, 0.07, 0.03, 0.0, 0.01, 0.19, 0.11, 0.02, 0.23, 0.27, 0.29, 0.11, 0.28, 0.21, 0.27, 0.27, 0.29, 0.32, 0.28, 0.4, 0.3, 0.23, 0.29, 0.15, 0.24, 0.2, 0.25, 0.23, 0.34, 0.26, 0.26, 0.33, 0.18, 0.18, 0.3, 0.06, 0.11, 0.26, 0.2, 0.16, 0.04, 0.19, 0.26, 0.57, 0.33, 0.1, 0.32, 0.09, 0.21, 0.17, 0.23, 0.35, 0.26, 0.35, 0.42, 0.18, 0.28, 0.22, 0.41, 0.2, 0.05, 0.2, 0.3, 0.28, 0.32, 0.15, 0.33, 0.22, 0.21, 0.31, 0.1, 0.18, 0.53, 0.3, 0.25, 0.18, 0.29, 0.41, 0.33, 0.47, 0.26, 0.36, 0.25, 0.25, 0.31, 0.2, 0.42, 0.22, 0.17, 0.26, 0.45, 0.44, 0.29, 0.37, 0.3, 0.29, 0.45, 0.05, 0.37, 0.35, 0.58, 0.2, 0.29, 0.34, 0.39, 0.22, 0.23, 0.1, 0.32, 0.3, 0.29, 0.3, 0.22, 0.33, 0.28, 0.3, 0.25, 0.33, 0.28, 0.3, 0.26, 0.3, 0.24, 0.22, 0.39, 0.29, 0.06, 0.11, 0.16, 0.13, 0.08, 0.37, 0.06, 0.25, 0.1, 0.23, 0.16, 0.15, 0.37, 0.27, 0.08, 0.27, 0.13, 0.1, 0.29, 0.08, 0.18, 0.16, 0.17, 0.21, 0.1, 0.08, 0.15, 0.19, 0.27, 0.23, 0.18, 0.2, 0.11, 0.1, 0.18, 0.17, 0.09, 0.11, 0.28, 0.08, 0.21, 0.09, 0.16, 0.24, 0.09, 0.0, 0.13, 0.11, 0.12, 0.1, 0.24, 0.15, 0.13, 0.25, 0.22, 0.12, 0.12, 0.58, 0.08, 0.7, 0.53, 0.77, 0.45, 0.72, 0.09, 0.71, 0.22, 0.25, 0.28, 0.53, 0.11, 0.26, 0.07, 0.61, 0.48, 0.61, 0.23, 0.65, 0.58, 0.6, 0.72, 0.09, 0.64, 0.69, 0.63, 0.54, 0.08, 0.58, 0.7, 0.26, 0.61, 0.5, 0.67, 0.18, 0.12, 0.6, 0.68, 0.26, 0.67, 0.16, 0.25, 0.31, 0.16, 0.24, 0.22, 0.27, 0.25, 0.19, 0.29, 0.32, 0.46, 0.21, 0.25, 0.16, 0.18, 0.15, 0.35, 0.25, 0.28, 0.18, 0.21, 0.26, 0.3, 0.26, 0.39, 0.4, 0.3, 0.27, 0.25, 0.27, 0.25, 0.16, 0.47, 0.26, 0.2, 0.18, 0.7, 0.14, 0.45, 0.68, 0.54, 0.83, 0.5, 0.57, 0.8, 0.54, 0.7, 0.75, 0.27, 0.69, 0.73, 0.78, 0.68, 0.59, 0.7, 0.65, 0.76, 0.57, 0.42, 0.68, 0.39, 0.71, 0.65, 0.27, 0.07, 0.16, 0.48, 0.05, 0.04, 0.14, 0.45, 0.15, 0.03, 0.06, 0.17, 0.22, 0.16, 0.23, 0.17, 0.18, 0.12, 0.21, 0.44, 0.18, 0.19, 0.03, 0.03, 0.23, 0.4, 0.58, 0.01, 0.08, 0.3, 0.0, 0.04, 0.22, 0.37, 0.06, 0.1, 0.03, 0.11, 0.01, 0.04, 0.06, 0.07, 0.01, 0.03, 0.2, 0.03, 0.01, 0.04, 0.01, 0.29, 0.06, 0.04, 0.22, 0.54, 0.26, 0.13, 0.17, 0.4, 0.39, 0.43, 0.49, 0.01, 0.14, 0.81, 0.89, 0.65, 0.72, 0.83, 0.85, 0.76, 0.66, 0.56, 0.7, 0.84, 0.63, 0.78, 0.62, 0.8, 0.74, 0.71, 0.82, 0.76, 0.81, 0.74, 0.78, 0.84, 0.9, 0.76, 0.85, 0.78, 0.86, 0.72, 0.8, 0.86, 0.86, 0.75, 0.39, 0.73, 0.72, 0.83, 0.64, 0.83, 0.78, 0.62, 0.81, 0.77, 0.83, 0.73, 0.72, 0.84, 0.87, 0.74, 0.88, 0.86, 0.88, 0.49, 0.82, 0.65, 0.88, 0.9, 0.81, 0.85, 0.88, 0.93, 0.87, 0.85, 0.93, 0.93, 0.96, 0.94, 0.76, 0.91, 0.93, 0.94, 0.92, 0.89, 0.88, 0.89, 0.95, 0.09, 0.67, 0.11, 0.03, 0.12, 0.63, 0.55, 0.39, 0.14, 0.77, 0.61, 0.76, 0.13, 0.36, 0.65, 0.75, 0.24, 0.52, 0.74, 0.69, 0.74, 0.57, 0.38, 0.61, 0.69, 0.72, 0.65, 0.72, 0.72, 0.63, 0.68, 0.27, 0.24, 0.64, 0.6, 0.59, 0.17, 0.02, 0.01, 0.24, 0.0, 0.01, 0.03, 0.0, 0.0, 0.01, 0.01, 0.01, 0.02, 0.01, 0.0, 0.03, 0.01, 0. ...

# %% [markdown]
# ### Upper New York contains most of the Schools with Hispanics
# Majority of the **hispanic** population are living in **Upper New York**. Again, notice how there are a few Hispanics in Central New York while there are a majority of Blacks in Central New York.

# %%
data = [
    {
        'x': df["Longitude"],
        'y': df["Latitude"],
        'text': df["School Name"],
        'mode': 'markers',
        'marker': {
            'color': df["Percent Hispanic"],
            'size': df["School Income Estimate"]/4500,
            'showscale': True,
            'colorscale':'Portland'
        }
    }
]

layout= go.Layout(
    title= 'New York Hispanic Student Ratio Of School',
    xaxis= dict(
        title= 'Longitude'
    ),
    yaxis=dict(
        title='Latitude'
    )
)
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='scatter_hover_labels')
# Out:
# <div id="382796c8-d38e-47b4-87ce-80b3e7425c25" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '382796c8-d38e-47b4-87ce-80b3e7425c25',
#             [{"marker": {"colorscale": "Portland", "showscale": true, "color": [0.6, 0.63, 0.49, 0.63, 0.65, 0.66, 0.43, 0.55, 0.78, 0.78, 0.12, 0.64, 0.57, 0.55, 0.21, 0.63, 0.39, 0.34, 0.35, 0.58, 0.53, 0.11, 0.37, 0.22, 0.09, 0.12, 0.07, 0.25, 0.3, 0.13, 0.1, 0.04, 0.42, 0.13, 0.05, 0.14, 0.21, 0.5, 0.09, 0.22, 0.03, 0.21, 0.05, 0.14, 0.14, 0.27, 0.1, 0.19, 0.3, 0.1, 0.27, 0.23, 0.14, 0.37, 0.08, 0.09, 0.1, 0.07, 0.11, 0.13, 0.09, 0.07, 0.13, 0.46, 0.12, 0.16, 0.2, 0.29, 0.35, 0.16, 0.19, 0.6, 0.2, 0.47, 0.21, 0.12, 0.56, 0.16, 0.42, 0.15, 0.63, 0.27, 0.46, 0.68, 0.17, 0.3, 0.45, 0.13, 0.34, 0.38, 0.29, 0.12, 0.26, 0.99, 0.55, 0.38, 0.43, 0.18, 0.17, 0.09, 0.44, 0.39, 0.13, 0.14, 0.27, 0.37, 0.62, 0.19, 0.51, 0.61, 0.53, 0.67, 0.83, 0.64, 0.68, 0.55, 0.64, 0.68, 0.87, 0.63, 0.91, 0.61, 0.51, 0.82, 0.5, 0.53, 0.56, 0.29, 0.6, 0.64, 0.31, 0.47, 0.51, 0.48, 0.34, 0.41, 0.42, 0.51, 0.37, 0.24, 0.36, 0.77, 0.3, 0.4, 0.33, 0.4, 0.39, 0.39, 0.14, 0.44, 0.23, 0.43, 0.28, 0.23, 0.91, 0.92, 0.96, 0.97, 0.84, 0.96, 0.93, 0.94, 0.96, 0.95, 0.98, 0.96, 0.96, 0.74, 0.92, 0.84, 0.58, 0.96, 0.92, 0.85, 0.96, 0.93, 0.84, 0.77, 0.92, 0.91, 0.46, 0.93, 0.95, 0.85, 0.91, 0.85, 0.91, 0.94, 1.0, 0.94, 0.58, 0.64, 0.97, 0.74, 0.71, 0.64, 0.87, 0.67, 0.75, 0.69, 0.71, 0.68, 0.64, 0.69, 0.57, 0.69, 0.73, 0.7, 0.83, 0.72, 0.79, 0.74, 0.74, 0.63, 0.72, 0.72, 0.62, 0.81, 0.76, 0.67, 0.65, 0.64, 0.71, 0.77, 0.8, 0.62, 0.72, 0.71, 0.4, 0.64, 0.56, 0.64, 0.51, 0.78, 0.54, 0.73, 0.6, 0.7, 0.61, 0.55, 0.78, 0.62, 0.76, 0.57, 0.77, 0.59, 0.77, 0.67, 0.68, 0.58, 0.59, 0.63, 0.68, 0.77, 0.65, 0.69, 0.56, 0.45, 0.69, 0.72, 0.81, 0.68, 0.56, 0.64, 0.52, 0.71, 0.61, 0.74, 0.74, 0.68, 0.8, 0.52, 0.71, 0.8, 0.71, 0.53, 0.54, 0.69, 0.6, 0.67, 0.67, 0.48, 0.89, 0.61, 0.63, 0.39, 0.79, 0.68, 0.64, 0.59, 0.73, 0.75, 0.87, 0.67, 0.66, 0.66, 0.67, 0.77, 0.65, 0.7, 0.67, 0.73, 0.57, 0.66, 0.62, 0.7, 0.67, 0.71, 0.78, 0.58, 0.68, 0.79, 0.77, 0.8, 0.85, 0.73, 0.62, 0.42, 0.71, 0.84, 0.72, 0.78, 0.8, 0.59, 0.7, 0.63, 0.68, 0.67, 0.49, 0.69, 0.86, 0.76, 0.68, 0.7, 0.6, 0.56, 0.9, 0.79, 0.78, 0.68, 0.76, 0.72, 0.75, 0.83, 0.85, 0.78, 0.79, 0.74, 0.88, 0.7, 0.82, 0.77, 0.85, 0.82, 0.74, 0.85, 0.99, 0.6, 0.84, 0.85, 0.82, 0.75, 0.83, 0.85, 0.72, 0.76, 0.84, 0.84, 0.28, 0.28, 0.24, 0.43, 0.19, 0.42, 0.22, 0.49, 0.16, 0.54, 0.61, 0.36, 0.37, 0.66, 0.35, 0.44, 0.36, 0.5, 0.26, 0.41, 0.29, 0.25, 0.33, 0.21, 0.29, 0.27, 0.23, 0.26, 0.41, 0.53, 0.33, 0.25, 0.57, 0.31, 0.4, 0.29, 0.64, 0.65, 0.32, 0.27, 0.57, 0.27, 0.64, 0.72, 0.68, 0.68, 0.71, 0.76, 0.71, 0.74, 0.77, 0.67, 0.63, 0.5, 0.76, 0.71, 0.8, 0.78, 0.84, 0.61, 0.7, 0.67, 0.76, 0.77, 0.72, 0.67, 0.71, 0.59, 0.57, 0.65, 0.7, 0.69, 0.69, 0.64, 0.8, 0.52, 0.59, 0.71, 0.69, 0.12, 0.11, 0.14, 0.11, 0.21, 0.11, 0.45, 0.37, 0.1, 0.35, 0.03, 0.18, 0.32, 0.27, 0.23, 0.19, 0.24, 0.25, 0.22, 0.14, 0.11, 0.29, 0.52, 0.14, 0.17, 0.14, 0.28, 0.67, 0.8, 0.8, 0.46, 0.43, 0.19, 0.82, 0.5, 0.78, 0.62, 0.23, 0.8, 0.63, 0.42, 0.65, 0.81, 0.78, 0.73, 0.76, 0.51, 0.62, 0.74, 0.67, 0.59, 0.72, 0.56, 0.33, 0.88, 0.31, 0.51, 0.91, 0.11, 0.26, 0.26, 0.09, 0.19, 0.12, 0.6, 0.37, 0.1, 0.51, 0.27, 0.55, 0.84, 0.22, 0.19, 0.41, 0.77, 0.32, 0.22, 0.47, 0.08, 0.24, 0.39, 0.47, 0.35, 0.2, 0.45, 0.36, 0.34, 0.45, 0.75, 0.33, 0.14, 0.08, 0.28, 0.25, 0.11, 0.14, 0.17, 0.32, 0.38, 0.22, 0.14, 0.25, 0.19, 0.31, 0.18, 0.23, 0.29, 0.09, 0.21, 0.13, 0.23, 0.19, 0.1, 0.06, 0.18, 0.09, 0.11, 0.1, 0.25, 0.17, 0.1, 0.1, 0.21, 0.5, 0.19, 0.2, 0.13, 0.3, 0.14, 0.13, 0.3, 0.15, 0.15, 0.08, 0.12, 0.14, 0.13, 0.1, 0.21, 0.08, 0.08, 0.05, 0.29, 0.11, 0.08, 0.07, 0.05, 0.1, 0.08, 0.07, 0.03, 0.11, 0.12, 0.05, 0.02, 0.02, 0.04, 0.15, 0.05, 0.04, 0.05, 0.07, 0.02, 0.06, 0.07, 0.03, 0.8, 0.28, 0.82, 0.95, 0.79, 0.32, 0.41, 0.26, 0.77, 0.22, 0.35, 0.21, 0.33, 0.43, 0.3, 0.23, 0.7, 0.33, 0.23, 0.2, 0.23, 0.37, 0.51, 0.24, 0.26, 0.24, 0.3, 0.24, 0.23, 0.34, 0.28, 0.66, 0.68, 0.33, 0.36, 0.37, 0.78, 0.3, 0.28, 0.31, 0.05, 0.25, 0.25, 0.04, 0.31, 0.22, 0.1, 0.32, 0.5, 0.19, 0.21, 0.25, ...

# %%
# Static Figure
# Set up the matplotlib figure
f, axes = plt.subplots(ncols=2, figsize=(15, 6))

df.plot(kind="scatter", x="Longitude", y="Latitude", ax=axes[0],
    s=df['Economic Need Index']*100, c="Percent Black", cmap=plt.get_cmap("jet"),label='Schools', title='Black Population Percentage of Schools',
    colorbar=True, alpha=0.3, figsize=(15,7))

df.plot(kind="scatter", x="Longitude", y="Latitude", ax=axes[1],
    s=df['Economic Need Index']*100, c="Percent Hispanic", cmap=plt.get_cmap("jet"),label='Schools', title='Hispanic Population Percentage of Schools',
    colorbar=True, alpha=0.3, figsize=(15,7))

plt.legend()
plt.show()

# %% [markdown]
# <a id='asian_white_geomap'></a>
# # New York Map of Asian/White Percentage of Schools

# %% [markdown]
# The **Asian** population are mostly living in Central New York.
#
# The **White** Population has a very noticeable cluster near the **edge and lower** parts of New York.

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(ncols=2, figsize=(15, 6))

df.plot(kind="scatter", x="Longitude", y="Latitude", ax=axes[0],
    s=df['Economic Need Index']*100, c="Percent Asian", label='Schools', title='Asian Population Percentage of Schools',
    colorbar=True, alpha=0.3, figsize=(15,5))

df.plot(kind="scatter", x="Longitude", y="Latitude", ax=axes[1],
    s=df['Economic Need Index']*130, c="Percent White", label='Schools', title='White Population Percentage of Schools',
    colorbar=True, alpha=1, figsize=(15,5))

plt.legend()
plt.show()

# %% [markdown]
# # Race Percentage Distribution from Schools
# ***
#
# **Interesting Find:**
#
# - Majority of **Whites and Asians** are representing **10%** of the school's population
# - **Blacks and Hispanics** represent majority of the school's population

# %% [markdown]
# ### White and Asian Distribution

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(ncols=2, figsize=(15, 6))

# Graph Employee Satisfaction
sns.distplot(df['Percent Asian'], kde=False, color="g", ax=axes[0], bins=25).set_title('% Asian Distribution')
axes[0].set_ylabel('School Count')

# Graph Employee Evaluation
sns.distplot(df['Percent White'], kde=False, color="r", ax=axes[1], bins=25).set_title('% White Distribution')
axes[1].set_ylabel('Employee Count')
# Out:
# Text(0,0.5,'Employee Count')

# %% [markdown]
# ### Blacks and Hispanics Distribution

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(ncols=2, figsize=(15, 6))

# Graph Employee Average Monthly Hours
sns.distplot(df['Percent Black'], kde=False, color="b", ax=axes[0], bins=35).set_title('% Black Distribution')
axes[0].set_ylabel('Employee Count')

# Graph Employee Average Monthly Hours
sns.distplot(df['Percent Hispanic'], kde=False, color="r", ax=axes[1], bins=35).set_title('% Hispanic Distribution')
axes[1].set_ylabel('Employee Count')
# Out:
# Text(0,0.5,'Employee Count')

# %%
df.head(1)
# Out:
#   Adjusted Grade New? Other Location Code in LCGMS                School Name  \
# 0            NaN  NaN                          NaN  P.S. 015 ROBERTO CLEMENTE
#
#        SED Code Location Code  District   Latitude  Longitude  \
# 0  310100010015        01M015         1  40.721834 -73.978766
#
#                     Address (Full)      City    Zip                Grades  \
# 0  333 E 4TH ST NEW YORK, NY 10009  NEW YORK  10009  PK,0K,01,02,03,04,05
#
#   Grade Low Grade High Community School?  Economic Need Index  \
# 0        PK         05               Yes                0.919
#
#    School Income Estimate Percent ELL  Percent Asian  Percent Black  \
# 0                31141.72          9%           0.05           0.32
#
#    Percent Hispanic  Percent Black / Hispanic  Percent White  \
# 0               0.6                      0.92           0.01
#
#    Student Attendance Rate  Percent of Students Chronically Absent  \
# 0                     0.94                                    0.18
#
#    Rigorous Instruction % Rigorous Instruction Rating  \
# 0                    0.89              Meeting Target
#
#    Collaborative Teachers % Collaborative Teachers Rating  \
# 0                      0.94                Meeting Target
#
#    Supportive Environment % Supportive Environment Rating  \
# 0                      0.86              Exceeding Target
#
#    Effective School Leadership % Effective School Leadership Rating  \
# 0                           0.91                   Exceeding Target
#
#    Strong Family-Community Ties % Strong Family-Community Ties Rating  \
# 0                            0.85                      Meeting Target
#
#    Trust %      Trust Rating Student Achievement Rating  \
# 0     0.94  Exceeding Target         Approaching Target
#
#    Average ELA Proficiency  Average Math Proficiency  \
# 0                     2.14                      2.17
#
#    Grade 3 ELA - All Students Tested  Grade 3 ELA 4s - All Students  \
# 0                                 20                              0
#
#    Grade 3 ELA 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 3 ELA 4s - Black or African American  \
# 0                                           0
#
#    Grade 3 ELA 4s - Hispanic or Latino  \
# 0                                    0
#
#    Grade 3 ELA 4s - Asian or Pacific Islander  Grade 3 ELA 4s - White  \
# 0                                           0                       0
#
#    Grade 3 ELA 4s - Multiracial  Grade 3 ELA 4s - Limited English Proficient  \
# 0                             0                                            0
#
#    Grade 3 ELA 4s - Economically Disadvantaged  \
# 0                                            0
#
#    Grade 3 Math - All Students tested  Grade 3 Math 4s - All Students  \
# 0                                  21                               0
#
#    Grade 3 Math 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 3 Math 4s - Black or African American  \
# 0                                            0
#
#    Grade 3 Math 4s - Hispanic or Latino  \
# 0                                     0
#
#    Grade 3 Math 4s - Asian or Pacific Islander  Grade 3 Math 4s - White  \
# 0                                            0                        0
#
#    Grade 3 Math 4s - Multiracial  \
# 0                              0
#
#    Grade 3 Math 4s - Limited English Proficient  \
# 0                                             0
#
#    Grade 3 Math 4s - Economically Disadvantaged  \
# 0                                             0
#
#    Grade 4 ELA - All Students Tested  Grade 4 ELA 4s - All Students  \
# 0                                 15                              0
#
#    Grade 4 ELA 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 4 ELA 4s - Black or African American  \
# 0                                           0
#
#    Grade 4 ELA 4s - Hispanic or Latino  \
# 0                                    0
#
#    Grade 4 ELA 4s - Asian or Pacific Islander  Grade 4 ELA 4s - White  \
# 0                                           0                       0
#
#    Grade 4 ELA 4s - Multiracial  Grade 4 ELA 4s - Limited English Proficient  \
# 0                             0                                            0
#
#    Grade 4 ELA 4s - Economically Disadvantaged  \
# 0                                            0
#
#    Grade 4 Math - All Students Tested  Grade 4 Math 4s - All Students  \
# 0                                  15                               2
#
#    Grade 4 Math 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 4 Math 4s - Black or African American  \
# 0                                            0
#
#    Grade 4 Math 4s - Hispanic or Latino  \
# 0                                     0
#
#    Grade 4 Math 4s - Asian or Pacific Islander  Grade 4 Math 4s - White  \
# 0                                            0                        0
#
#    Grade 4 Math 4s - Multiracial  \
# 0                              0
#
#    Grade 4 Math 4s - Limited English Proficient  \
# 0                                             0
#
#    Grade 4 Math 4s - Economically Disadvantaged  \
# 0                                             0
#
#    Grade 5 ELA - All Students Tested  Grade 5 ELA 4s - All Students  \
# 0                                 16                              0
#
#    Grade 5 ELA 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 5 ELA 4s - Black or African American  \
# 0                                           0
#
#    Grade 5 ELA 4s - Hispanic or Latino  \
# 0                                    0
#
#    Grade 5 ELA 4s - Asian or Pacific Islander  Grade 5 ELA 4s - White  \
# 0                                           0                       0
#
#    Grade 5 ELA 4s - Multiracial  Grade 5 ELA 4s - Limited English Proficient  \
# 0                             0                                            0
#
#    Grade 5 ELA 4s - Economically Disadvantaged  \
# 0                                            0
#
#    Grade 5 Math - All Students Tested  Grade 5 Math 4s - All Students  \
# 0                                  16                               0
#
#    Grade 5 Math 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 5 Math 4s - Black or African American  \
# 0                                            0
#
#    Grade 5 Math 4s - Hispanic or Latino  \
# 0                                     0
#
#    Grade 5 Math 4s - Asian or Pacific Islander  Grade 5 Math 4s - White  \
# 0                                            0                        0
#
#    Grade 5 Math 4s - Multiracial  \
# 0                              0
#
#    Grade 5 Math 4s - Limited English Proficient  \
# 0                                             0
#
#    Grade 5 Math 4s - Economically Disadvantaged  \
# 0                                             0
#
#    Grade 6 ELA - All Students Tested  Grade 6 ELA 4s - All Students  \
# 0                                  0                              0
#
#    Grade 6 ELA 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 6 ELA 4s - Black or African American  \
# 0                                           0
#
#    Grade 6 ELA 4s - Hispanic or Latino  \
# 0                                    0
#
#    Grade 6 ELA 4s - Asian or Pacific Islander  Grade 6 ELA 4s - White  \
# 0                                           0                       0
#
#    Grade 6 ELA 4s - Multiracial  Grade 6 ELA 4s - Limited English Proficient  \
# 0                             0                                            0
#
#    Grade 6 ELA 4s - Economically Disadvantaged  \
# 0                                            0
#
#    Grade 6 Math - All Students Tested  Grade 6 Math 4s - All Students  \
# 0                                   0                               0
#
#    Grade 6 Math 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 6 Math 4s - Black or African American  \
# 0                                            0
#
#    Grade 6 Math 4s - Hispanic or Latino  \
# 0                                     0
#
#    Grade 6 Math 4s - Asian or Pacific Islander  Grade 6 Math 4s - White  \
# 0                                            0                        0
#
#    Grade 6 Math 4s - Multiracial  \
# 0                              0
#
#    Grade 6 Math 4s - Limited English Proficient  \
# 0                                             0
#
#    Grade 6 Math 4s - Economically Disadvantaged  \
# 0                                             0
#
#    Grade 7 ELA - All Students Tested  Grade 7 ELA 4s - All Students  \
# 0                                  0                              0
#
#    Grade 7 ELA 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 7 ELA 4s - Black or African American  \
# 0                                           0
#
#    Grade 7 ELA 4s - Hispanic or Latino  \
# 0                                    0
#
#    Grade 7 ELA 4s - Asian or Pacific Islander  Grade 7 ELA 4s - White  \
# 0                                           0                       0
#
#    Grade 7 ELA 4s - Multiracial  Grade 7 ELA 4s - Limited English Proficient  \
# 0                             0                                            0
#
#    Grade 7 ELA 4s - Economically Disadvantaged  \
# 0                                            0
#
#    Grade 7 Math - All Students Tested  Grade 7 Math 4s - All Students  \
# 0                                   0                               0
#
#    Grade 7 Math 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 7 Math 4s - Black or African American  \
# 0                                            0
#
#    Grade 7 Math 4s - Hispanic or Latino  \
# 0                                     0
#
#    Grade 7 Math 4s - Asian or Pacific Islander  Grade 7 Math 4s - White  \
# 0                                            0                        0
#
#    Grade 7 Math 4s - Multiracial  \
# 0                              0
#
#    Grade 7 Math 4s - Limited English Proficient  \
# 0                                             0
#
#    Grade 7 Math 4s - Economically Disadvantaged  \
# 0                                             0
#
#    Grade 8 ELA - All Students Tested  Grade 8 ELA 4s - All Students  \
# 0                                  0                              0
#
#    Grade 8 ELA 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 8 ELA 4s - Black or African American  \
# 0                                           0
#
#    Grade 8 ELA 4s - Hispanic or Latino  \
# 0                                    0
#
#    Grade 8 ELA 4s - Asian or Pacific Islander  Grade 8 ELA 4s - White  \
# 0                                           0                       0
#
#    Grade 8 ELA 4s - Multiracial  Grade 8 ELA 4s - Limited English Proficient  \
# 0                             0                                            0
#
#    Grade 8 ELA 4s - Economically Disadvantaged  \
# 0                                            0
#
#    Grade 8 Math - All Students Tested  Grade 8 Math 4s - All Students  \
# 0                                   0                               0
#
#    Grade 8 Math 4s - American Indian or Alaska Native  \
# 0                                                  0
#
#    Grade 8 Math 4s - Black or African American  \
# 0                                            0
#
#    Grade 8 Math 4s - Hispanic or Latino  \
# 0                                     0
#
#    Grade 8 Math 4s - Asian or Pacific Islander  Grade 8 Math 4s - White  \
# 0                                            0                        0
#
#    Grade 8 Math 4s - Multiracial  \
# 0                              0
#
#    Grade 8 Math 4s - Limited English Proficient  \
# 0                                             0
#
#    Grade 8 Math 4s - Economically Disadvantaged
# 0                                             0

# %% [markdown]
# <a id='correlation'></a>
# # Correlation Matrix
# ***
#
# Using our numeric features, let's take a look at our correlation matrix. **Here are some interesting correlations:**
#
# ### Economic Need Index
# - Schools with **more White Students** have a **lower economic need index**, meaning the schools are operating just fine without the need of help.
# - Schools with **more Asian Students** have a **slightly lower economic need index**.
# - Schools with **more Black/Hispanic Students** have a **higher economic need index**, meaning the schools are in need of help.
# - Schools with **more Chronically Absent Students** have a **higher economic need index**
#
# ### School Income Estimate
# - Schools with **more White/Asian Students** have a **higher school income estimate**.
# - Schools with **more Black/Hispanic Students** have a **lower school income estimate**

# %%
for index,colname in enumerate(df.columns.values):
    print(index, colname)
# Out:
# 0 Adjusted Grade
# 1 New?
# 2 Other Location Code in LCGMS
# 3 School Name
# 4 SED Code
# 5 Location Code
# 6 District
# 7 Latitude
# 8 Longitude
# 9 Address (Full)
# 10 City
# 11 Zip
# 12 Grades
# 13 Grade Low
# 14 Grade High
# 15 Community School?
# 16 Economic Need Index
# 17 School Income Estimate
# 18 Percent ELL
# 19 Percent Asian
# 20 Percent Black
# 21 Percent Hispanic
# 22 Percent Black / Hispanic
# 23 Percent White
# 24 Student Attendance Rate
# 25 Percent of Students Chronically Absent
# 26 Rigorous Instruction %
# 27 Rigorous Instruction Rating
# 28 Collaborative Teachers %
# 29 Collaborative Teachers Rating
# 30 Supportive Environment %
# 31 Supportive Environment Rating
# 32 Effective School Leadership %
# 33 Effective School Leadership Rating
# 34 Strong Family-Community Ties %
# 35 Strong Family-Community Ties Rating
# 36 Trust %
# 37 Trust Rating
# 38 Student Achievement Rating
# 39 Average ELA Proficiency
# 40 Average Math Proficiency
# 41 Grade 3 ELA - All Students Tested
# 42 Grade 3 ELA 4s - All Students
# 43 Grade 3 ELA 4s - American Indian or Alaska Native
# 44 Grade 3 ELA 4s - Black or African American
# 45 Grade 3 ELA 4s - Hispanic or Latino
# 46 Grade 3 ELA 4s - Asian or Pacific Islander
# 47 Grade 3 ELA 4s - White
# 48 Grade 3 ELA 4s - Multiracial
# 49 Grade 3 ELA 4s - Limited English Proficient
# 50 Grade 3 ELA 4s - Economically Disadvantaged
# 51 Grade 3 Math - All Students tested
# 52 Grade 3 Math 4s - All Students
# 53 Grade 3 Math 4s - American Indian or Alaska Native
# 54 Grade 3 Math 4s - Black or African American
# 55 Grade 3 Math 4s - Hispanic or Latino
# 56 Grade 3 Math 4s - Asian or Pacific Islander
# 57 Grade 3 Math 4s - White
# 58 Grade 3 Math 4s - Multiracial
# 59 Grade 3 Math 4s - Limited English Proficient
# 60 Grade 3 Math 4s - Economically Disadvantaged
# 61 Grade 4 ELA - All Students Tested
# 62 Grade 4 ELA 4s - All Students
# 63 Grade 4 ELA 4s - American Indian or Alaska Native
# 64 Grade 4 ELA 4s - Black or African American
# 65 Grade 4 ELA 4s - Hispanic or Latino
# 66 Grade 4 ELA 4s - Asian or Pacific Islander
# 67 Grade 4 ELA 4s - White
# 68 Grade 4 ELA 4s - Multiracial
# 69 Grade 4 ELA 4s - Limited English Proficient
# 70 Grade 4 ELA 4s - Economically Disadvantaged
# 71 Grade 4 Math - All Students Tested
# 72 Grade 4 Math 4s - All Students
# 73 Grade 4 Math 4s - American Indian or Alaska Native
# 74 Grade 4 Math 4s - Black or African American
# 75 Grade 4 Math 4s - Hispanic or Latino
# 76 Grade 4 Math 4s - Asian or Pacific Islander
# 77 Grade 4 Math 4s - White
# 78 Grade 4 Math 4s - Multiracial
# 79 Grade 4 Math 4s - Limited English Proficient
# 80 Grade 4 Math 4s - Economically Disadvantaged
# 81 Grade 5 ELA - All Students Tested
# 82 Grade 5 ELA 4s - All Students
# 83 Grade 5 ELA 4s - American Indian or Alaska Native
# 84 Grade 5 ELA 4s - Black or African American
# 85 Grade 5 ELA 4s - Hispanic or Latino
# 86 Grade 5 ELA 4s - Asian or Pacific Islander
# 87 Grade 5 ELA 4s - White
# 88 Grade 5 ELA 4s - Multiracial
# 89 Grade 5 ELA 4s - Limited English Proficient
# 90 Grade 5 ELA 4s - Economically Disadvantaged
# 91 Grade 5 Math - All Students Tested
# 92 Grade 5 Math 4s - All Students
# 93 Grade 5 Math 4s - American Indian or Alaska Native
# 94 Grade 5 Math 4s - Black or African American
# 95 Grade 5 Math 4s - Hispanic or Latino
# 96 Grade 5 Math 4s - Asian or Pacific Islander
# 97 Grade 5 Math 4s - White
# 98 Grade 5 Math 4s - Multiracial
# 99 Grade 5 Math 4s - Limited English Proficient
# 100 Grade 5 Math 4s - Economically Disadvantaged
# 101 Grade 6 ELA - All Students Tested
# 102 Grade 6 ELA 4s - All Students
# 103 Grade 6 ELA 4s - American Indian or Alaska Native
# 104 Grade 6 ELA 4s - Black or African American
# 105 Grade 6 ELA 4s - Hispanic or Latino
# 106 Grade 6 ELA 4s - Asian or Pacific Islander
# 107 Grade 6 ELA 4s - White
# 108 Grade 6 ELA 4s - Multiracial
# 109 Grade 6 ELA 4s - Limited English Proficient
# 110 Grade 6 ELA 4s - Economically Disadvantaged
# 111 Grade 6 Math - All Students Tested
# 112 Grade 6 Math 4s - All Students
# 113 Grade 6 Math 4s - American Indian or Alaska Native
# 114 Grade 6 Math 4s - Black or African American
# 115 Grade 6 Math 4s - Hispanic or Latino
# 116 Grade 6 Math 4s - Asian or Pacific Islander
# 117 Grade 6 Math 4s - White
# 118 Grade 6 Math 4s - Multiracial
# 119 Grade 6 Math 4s - Limited English Proficient
# 120 Grade 6 Math 4s - Economically Disadvantaged
# 121 Grade 7 ELA - All Students Tested
# 122 Grade 7 ELA 4s - All Students
# 123 Grade 7 ELA 4s - American Indian or Alaska Native
# 124 Grade 7 ELA 4s - Black or African American
# 125 Grade 7 ELA 4s - Hispanic or Latino
# 126 Grade 7 ELA 4s - Asian or Pacific Islander
# 127 Grade 7 ELA 4s - White
# 128 Grade 7 ELA 4s - Multiracial
# 129 Grade 7 ELA 4s - Limited English Proficient
# 130 Grade 7 ELA 4s - Economically Disadvantaged
# 131 Grade 7 Math - All Students Tested
# 132 Grade 7 Math 4s - All Students
# 133 Grade 7 Math 4s - American Indian or Alaska Native
# 134 Grade 7 Math 4s - Black or African American
# 135 Grade 7 Math 4s - Hispanic or Latino
# 136 Grade 7 Math 4s - Asian or Pacific Islander
# 137 Grade 7 Math 4s - White
# 138 Grade 7 Math 4s - Multiracial
# 139 Grade 7 Math 4s - Limited English Proficient
# 140 Grade 7 Math 4s - Economically Disadvantaged
# 141 Grade 8 ELA - All Students Tested
# 142 Grade 8 ELA 4s - All Students
# 143 Grade 8 ELA 4s - American Indian or Alaska Native
# 144 Grade 8 ELA 4s - Black or African American
# 145 Grade 8 ELA 4s - Hispanic or Latino
# 146 Grade 8 ELA 4s - Asian or Pacific Islander
# 147 Grade 8 ELA 4s - White
# 148 Grade 8 ELA 4s - Multiracial
# 149 Grade 8 ELA 4s - Limited English Proficient
# 150 Grade 8 ELA 4s - Economically Disadvantaged
# 151 Grade 8 Math - All Students Tested
# 152 Grade 8 Math 4s - All Students
# 153 Grade 8 Math 4s - American Indian or Alaska Native
# 154 Grade 8 Math 4s - Black or African American
# 155 Grade 8 Math 4s - Hispanic or Latino
# 156 Grade 8 Math 4s - Asian or Pacific Islander
# 157 Grade 8 Math 4s - White
# 158 Grade 8 Math 4s - Multiracial
# 159 Grade 8 Math 4s - Limited English Proficient
# 160 Grade 8 Math 4s - Economically Disadvantaged

# %% [markdown]
# <b>We are interested in
#
# Index ColumnName</b>
# __________________________________________________
# 17 School Income Estimate
#
# 18 Percent ELL
#
# 19 Percent Asian
#
# 20 Percent Black
#
# 21 Percent Hispanic
#
# 22 Percent Black / Hispanic
#
# 23 Percent White
#
# 24 Student Attendance Rate
#
# 25 Percent of Students Chronically Absent
#
# 26 Rigorous Instruction %
#
# 27 Rigorous Instruction Rating
#
# 28 Collaborative Teachers %
#
# 29 Collaborative Teachers Rating
#
# 30 Supportive Environment %
#
# 31 Supportive Environment Rating
#
# 32 Effective School Leadership %
#
# 33 Effective School Leadership Rating
#
# 34 Strong Family-Community Ties %
#
# 35 Strong Family-Community Ties Rating
#
# 36 Trust %

# %%
df2 = df.iloc[:,[16,17,19,20,21,22,23,24,25,26,28,30,32,34,36]]
#Correlation Matrix
corr = df2.corr()
corr = (corr)
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            cmap="RdYlGn", center=0)

# %% [markdown]
# <a id='race_economic'></a>
# # Student Race & Economic Need Index
# ***
#
# This is a really interesting find:
# - Schools with a **Higher White and Asian** Population tend to have a **Lower Economic Need Index Score**.
# - Schools with a **Higher Hispanic and Black** Population tend to have a **Higher Economic Need Index Score**.
#
# Our main focus should be to try and understand what is making the **Hispanic and Black** Students in need of help.

# %%
f, axes = plt.subplots(2, 2, figsize=(19, 9), sharex=True)
sns.despine(left=True)

sns.regplot(x=df["Economic Need Index"], y=df["Percent Asian"], color='purple', ax=axes[0, 0], line_kws={"color": "black"})
sns.regplot(x=df["Economic Need Index"], y=df["Percent White"], color='g', ax=axes[0, 1], line_kws={"color": "black"})
sns.regplot(x=df["Economic Need Index"], y=df["Percent Black"], color='b', ax=axes[1, 0], line_kws={"color": "black"})
sns.regplot(x=df["Economic Need Index"], y=df["Percent Hispanic"], color='r', ax=axes[1, 1], line_kws={"color": "black"})

axes[0,0].set_title('Ecnomic Need Index (Asian)')
axes[0,1].set_title('Ecnomic Need Index (White)')
axes[1,0].set_title('Ecnomic Need Index (Black)')
axes[1,1].set_title('Ecnomic Need Index (Hispanic)')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# <a id='school_attendance'></a>
# # Schools and Student Attendance
# ***
#
# ### Question
# Is there a difference between the students in schools with higher-to-lower attendance rate?
#
# Our goal is to find good **proxies** for **underdeveloped schools**. Let's see if there are any differences between the attendance rate.
#
# ### Idea
# With these two groups, we can perform some **hypothesis testing** to see if there really are any statistical significance of different metrics (ex. Income, Economic Index Need, and Race) between Schools with 30% Absent Rate and 10% Absent Rate.
#
# ### Interesting Find
# As you can see, the **average absent rate** for students is about **20%**.
#
# Let's dive in deep to understand if there are any real differences between schools with an **absent rate of <= 11%** and an **absent rate of >= 30%**.

# %%
df['Percent of Students Chronically Absent'].mean()*100
# Out:
# 21.574979951884522

# %%
# Create a dataframe of schools with an absent rate of 30% or more.
absent_30 = df[df['Percent of Students Chronically Absent']>=.30]

# Create a dataframe of schools with an absent rate of 11% or less.
absent_11 = df[df['Percent of Students Chronically Absent']<=.11]

# Exploring School Absent Rate 
df['Percent of Students Chronically Absent'].describe()
# Out:
# count    1247.000000
# mean        0.215750
# std         0.140716
# min         0.000000
# 25%         0.110000
# 50%         0.200000
# 75%         0.300000
# max         1.000000
# Name: Percent of Students Chronically Absent, dtype: float64

# %% [markdown]
# ## Schools with 30% Absent Ratio:
# - Average **Economic Need Index** at **84%**
# - Average **School Income** at **$33,000**
# - **Asians and Whites** make up about **5%** of the students in these schools.
# - **Blacks and Hispanics** make up about **95%** of the students in these schools.
#
# ## Schools with 10% Absent Ratio:
# - Average **Economic Need Index** at **48%**
# - Average **School Income** at **$64,000**
# - **Asians and Whites** make up about **52%** of the students in these schools.
# - **Blacks and Hispanics** make up about **48%** of the students in these schools.

# %% [markdown]
# ### Schools with 30% Absent Rate

# %%
absent_30.iloc[:,[15,16,17,23,19,20,21,22]].describe()
# Out:
#        Economic Need Index  School Income Estimate  Percent White  \
# count           330.000000              330.000000     330.000000
# mean              0.840624            24213.924788       0.025455
# std               0.080521            17646.702137       0.040520
# min               0.369000                0.000000       0.000000
# 25%               0.807500                0.000000       0.010000
# 50%               0.857500            27338.415000       0.020000
# 75%               0.898750            35521.105000       0.030000
# max               0.957000            79244.110000       0.460000
#
#        Percent Asian  Percent Black  Percent Hispanic  \
# count     330.000000     330.000000        330.000000
# mean        0.027212       0.455091          0.477121
# std         0.039312       0.225843          0.228938
# min         0.000000       0.010000          0.020000
# 25%         0.010000       0.260000          0.270000
# 50%         0.010000       0.440000          0.485000
# 75%         0.030000       0.660000          0.680000
# max         0.320000       0.950000          0.920000
#
#        Percent Black / Hispanic
# count                330.000000
# mean                   0.932121
# std                    0.066482
# min                    0.480000
# 25%                    0.920000
# 50%                    0.950000
# 75%                    0.970000
# max                    0.990000

# %% [markdown]
# ### Schools with 10% Absent Rate

# %%
absent_11.iloc[:,[3,15,16,17,23,19,20,21,22]].describe()
# Out:
#        Economic Need Index  School Income Estimate  Percent White  \
# count           326.000000              326.000000     326.000000
# mean              0.484862            44751.846319       0.254632
# std               0.226285            36657.241653       0.249776
# min               0.049000                0.000000       0.000000
# 25%               0.295250                0.000000       0.020000
# 50%               0.488500            46699.660000       0.180000
# 75%               0.682000            69124.027500       0.437500
# max               0.878000           181382.060000       0.910000
#
#        Percent Asian  Percent Black  Percent Hispanic  \
# count     326.000000     326.000000        326.000000
# mean        0.238436       0.187239          0.293374
# std         0.246289       0.272421          0.245842
# min         0.000000       0.000000          0.020000
# 25%         0.040000       0.020000          0.120000
# 50%         0.140000       0.060000          0.200000
# 75%         0.397500       0.220000          0.397500
# max         0.950000       0.970000          1.000000
#
#        Percent Black / Hispanic
# count                326.000000
# mean                   0.480644
# std                    0.325940
# min                    0.030000
# 25%                    0.200000
# 50%                    0.370000
# 75%                    0.870000
# max                    1.000000

# %% [markdown]
# ## Location of High and Low Absent Rate Schools
# ***

# %% [markdown]
# ## Shools with 30% Absent Rate
# The schools with **30%** absent rate are **more clumped** in the **Central** and **Upper** regions of New York.

# %%
data = [
    {
        'x': absent_30["Longitude"],
        'y': absent_30["Latitude"],
        'text': absent_30["School Name"],
        'mode': 'markers',
        'marker': {
            'color': df["Economic Need Index"],
            'size': df["School Income Estimate"]/4500,
            'showscale': True,
            'colorscale':'Portland'
        }
    }
]

layout= go.Layout(
    title= 'Schools with 30% Absent Rate',
    xaxis= dict(
        title= 'Longitude'
    ),
    yaxis=dict(
        title='Latitude'
    )
)
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='scatter_hover_labels')
# Out:
# <div id="d9df5f63-534b-4bb1-b4e9-102d4de0eb03" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'd9df5f63-534b-4bb1-b4e9-102d4de0eb03',
#             [{"marker": {"colorscale": "Portland", "showscale": true, "color": [0.919, 0.6409999999999999, 0.7440000000000001, 0.86, 0.73, 0.858, 0.499, 0.833, 0.8490000000000001, 0.861, 0.5589999999999999, 0.917, 0.8320000000000001, 0.7909999999999999, 0.36200000000000004, 0.7709999999999999, 0.451, 0.43, 0.44799999999999995, 0.764, 0.61, 0.257, 0.597, 0.769, 0.858, 0.17600000000000002, 0.10099999999999999, 0.293, 0.43, 0.153, 0.066, 0.785, 0.626, 0.075, 0.069, 0.068, 0.522, 0.645, 0.10400000000000001, 0.307, 0.578, 0.728, 0.616, 0.8370000000000001, 0.196, 0.36700000000000005, 0.11, 0.36, 0.271, 0.07400000000000001, 0.365, 0.2, 0.293, 0.429, 0.065, 0.131, 0.23600000000000002, 0.049, 0.114, 0.313, 0.064, 0.308, 0.0, 0.812, 0.059000000000000004, 0.258, 0.33, 0.358, 0.406, 0.46799999999999997, 0.0, 0.765, 0.564, 0.613, 0.221, 0.221, 0.599, 0.85, 0.5, 0.099, 0.843, 0.883, 0.503, 0.7390000000000001, 0.217, 0.69, 0.758, 0.078, 0.875, 0.8490000000000001, 0.8859999999999999, 0.18100000000000002, 0.304, 0.802, 0.6609999999999999, 0.778, 0.73, 0.0, 0.233, 0.134, 0.7909999999999999, 0.767, 0.162, 0.253, 0.7859999999999999, 0.47700000000000004, 0.899, 0.435, 0.779, 0.915, 0.89, 0.885, 0.866, 0.772, 0.902, 0.833, 0.843, 0.903, 0.902, 0.7509999999999999, 0.8590000000000001, 0.8170000000000001, 0.708, 0.836, 0.917, 0.865, 0.85, 0.38299999999999995, 0.722, 0.8420000000000001, 0.46, 0.8959999999999999, 0.8390000000000001, 0.903, 0.897, 0.835, 0.805, 0.8540000000000001, 0.875, 0.747, 0.899, 0.875, 0.893, 0.898, 0.8740000000000001, 0.892, 0.8170000000000001, 0.852, 0.7829999999999999, 0.507, 0.708, 0.8809999999999999, 0.536, 0.732, 0.8440000000000001, 0.851, 0.841, 0.823, 0.9009999999999999, 0.8009999999999999, 0.8240000000000001, 0.856, 0.882, 0.8170000000000001, 0.857, 0.8490000000000001, 0.8690000000000001, 0.8340000000000001, 0.75, 0.721, 0.406, 0.872, 0.8290000000000001, 0.7859999999999999, 0.8, 0.84, 0.7240000000000001, 0.604, 0.708, 0.713, 0.429, 0.838, 0.861, 0.779, 0.8640000000000001, 0.8340000000000001, 0.85, 0.84, 0.878, 0.777, 0.7559999999999999, 0.615, 0.867, 0.915, 0.905, 0.914, 0.863, 0.8909999999999999, 0.9229999999999999, 0.878, 0.91, 0.924, 0.9570000000000001, 0.89, 0.912, 0.879, 0.9059999999999999, 0.9059999999999999, 0.899, 0.872, 0.866, 0.903, 0.9279999999999999, 0.9079999999999999, 0.882, 0.885, 0.897, 0.9229999999999999, 0.799, 0.882, 0.498, 0.779, 0.922, 0.8959999999999999, 0.7509999999999999, 0.511, 0.7609999999999999, 0.922, 0.667, 0.86, 0.489, 0.9129999999999999, 0.8, 0.8759999999999999, 0.821, 0.872, 0.812, 0.851, 0.875, 0.9109999999999999, 0.9129999999999999, 0.73, 0.853, 0.823, 0.9059999999999999, 0.38799999999999996, 0.915, 0.8909999999999999, 0.7809999999999999, 0.723, 0.56, 0.818, 0.7559999999999999, 0.8759999999999999, 0.802, 0.639, 0.7959999999999999, 0.903, 0.9229999999999999, 0.877, 0.922, 0.8340000000000001, 0.935, 0.919, 0.9390000000000001, 0.91, 0.89, 0.9159999999999999, 0.8909999999999999, 0.87, 0.8740000000000001, 0.91, 0.904, 0.9, 0.91, 0.852, 0.9279999999999999, 0.888, 0.9279999999999999, 0.9009999999999999, 0.865, 0.8390000000000001, 0.861, 0.929, 0.885, 0.705, 0.872, 0.882, 0.8220000000000001, 0.934, 0.9159999999999999, 0.9009999999999999, 0.929, 0.8809999999999999, 0.892, 0.8190000000000001, 0.8909999999999999, 0.862, 0.938, 0.9129999999999999, 0.92, 0.8859999999999999, 0.8009999999999999, 0.898, 0.8759999999999999, 0.86, 0.909, 0.8029999999999999, 0.833, 0.816, 0.8640000000000001, 0.746, 0.8, 0.9229999999999999, 0.852, 0.8059999999999999, 0.905, 0.22699999999999998, 0.925, 0.91, 0.752, 0.8859999999999999, 0.9059999999999999, 0.7140000000000001, 0.8959999999999999, 0.821, 0.934, 0.8270000000000001, 0.35700000000000004, 0.925, 0.878, 0.903, 0.862, 0.7859999999999999, 0.843, 0.418, 0.907, 0.887, 0.909, 0.8059999999999999, 0.903, 0.821, 0.851, 0.85, 0.88, 0.885, 0.9179999999999999, 0.8370000000000001, 0.9229999999999999, 0.91, 0.836, 0.8240000000000001, 0.8740000000000001, 0.868, 0.894, 0.909, 0.857,  ...

# %% [markdown]
# ## Schools with 10% Absent Rate
# The scools with **10%** absent rate are **more dispersed** around the New York area.

# %%
data = [
    {
        'x': absent_11["Longitude"],
        'y': absent_11["Latitude"],
        'text': absent_11["School Name"],
        'mode': 'markers',
        'marker': {
            'color': df["Economic Need Index"],
            'size': df["School Income Estimate"]/4500,
            'showscale': True,
            'colorscale':'Portland'
        }
    }
]

layout= go.Layout(
    title= 'Schools with 10% Absent Rate',
    xaxis= dict(
        title= 'Longitude'
    ),
    yaxis=dict(
        title='Latitude'
    )
)
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='scatter_hover_labels')
# Out:
# <div id="62bd6962-6da9-479c-b22e-9c4621c02fdc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '62bd6962-6da9-479c-b22e-9c4621c02fdc',
#             [{"marker": {"colorscale": "Portland", "showscale": true, "color": [0.919, 0.6409999999999999, 0.7440000000000001, 0.86, 0.73, 0.858, 0.499, 0.833, 0.8490000000000001, 0.861, 0.5589999999999999, 0.917, 0.8320000000000001, 0.7909999999999999, 0.36200000000000004, 0.7709999999999999, 0.451, 0.43, 0.44799999999999995, 0.764, 0.61, 0.257, 0.597, 0.769, 0.858, 0.17600000000000002, 0.10099999999999999, 0.293, 0.43, 0.153, 0.066, 0.785, 0.626, 0.075, 0.069, 0.068, 0.522, 0.645, 0.10400000000000001, 0.307, 0.578, 0.728, 0.616, 0.8370000000000001, 0.196, 0.36700000000000005, 0.11, 0.36, 0.271, 0.07400000000000001, 0.365, 0.2, 0.293, 0.429, 0.065, 0.131, 0.23600000000000002, 0.049, 0.114, 0.313, 0.064, 0.308, 0.0, 0.812, 0.059000000000000004, 0.258, 0.33, 0.358, 0.406, 0.46799999999999997, 0.0, 0.765, 0.564, 0.613, 0.221, 0.221, 0.599, 0.85, 0.5, 0.099, 0.843, 0.883, 0.503, 0.7390000000000001, 0.217, 0.69, 0.758, 0.078, 0.875, 0.8490000000000001, 0.8859999999999999, 0.18100000000000002, 0.304, 0.802, 0.6609999999999999, 0.778, 0.73, 0.0, 0.233, 0.134, 0.7909999999999999, 0.767, 0.162, 0.253, 0.7859999999999999, 0.47700000000000004, 0.899, 0.435, 0.779, 0.915, 0.89, 0.885, 0.866, 0.772, 0.902, 0.833, 0.843, 0.903, 0.902, 0.7509999999999999, 0.8590000000000001, 0.8170000000000001, 0.708, 0.836, 0.917, 0.865, 0.85, 0.38299999999999995, 0.722, 0.8420000000000001, 0.46, 0.8959999999999999, 0.8390000000000001, 0.903, 0.897, 0.835, 0.805, 0.8540000000000001, 0.875, 0.747, 0.899, 0.875, 0.893, 0.898, 0.8740000000000001, 0.892, 0.8170000000000001, 0.852, 0.7829999999999999, 0.507, 0.708, 0.8809999999999999, 0.536, 0.732, 0.8440000000000001, 0.851, 0.841, 0.823, 0.9009999999999999, 0.8009999999999999, 0.8240000000000001, 0.856, 0.882, 0.8170000000000001, 0.857, 0.8490000000000001, 0.8690000000000001, 0.8340000000000001, 0.75, 0.721, 0.406, 0.872, 0.8290000000000001, 0.7859999999999999, 0.8, 0.84, 0.7240000000000001, 0.604, 0.708, 0.713, 0.429, 0.838, 0.861, 0.779, 0.8640000000000001, 0.8340000000000001, 0.85, 0.84, 0.878, 0.777, 0.7559999999999999, 0.615, 0.867, 0.915, 0.905, 0.914, 0.863, 0.8909999999999999, 0.9229999999999999, 0.878, 0.91, 0.924, 0.9570000000000001, 0.89, 0.912, 0.879, 0.9059999999999999, 0.9059999999999999, 0.899, 0.872, 0.866, 0.903, 0.9279999999999999, 0.9079999999999999, 0.882, 0.885, 0.897, 0.9229999999999999, 0.799, 0.882, 0.498, 0.779, 0.922, 0.8959999999999999, 0.7509999999999999, 0.511, 0.7609999999999999, 0.922, 0.667, 0.86, 0.489, 0.9129999999999999, 0.8, 0.8759999999999999, 0.821, 0.872, 0.812, 0.851, 0.875, 0.9109999999999999, 0.9129999999999999, 0.73, 0.853, 0.823, 0.9059999999999999, 0.38799999999999996, 0.915, 0.8909999999999999, 0.7809999999999999, 0.723, 0.56, 0.818, 0.7559999999999999, 0.8759999999999999, 0.802, 0.639, 0.7959999999999999, 0.903, 0.9229999999999999, 0.877, 0.922, 0.8340000000000001, 0.935, 0.919, 0.9390000000000001, 0.91, 0.89, 0.9159999999999999, 0.8909999999999999, 0.87, 0.8740000000000001, 0.91, 0.904, 0.9, 0.91, 0.852, 0.9279999999999999, 0.888, 0.9279999999999999, 0.9009999999999999, 0.865, 0.8390000000000001, 0.861, 0.929, 0.885, 0.705, 0.872, 0.882, 0.8220000000000001, 0.934, 0.9159999999999999, 0.9009999999999999, 0.929, 0.8809999999999999, 0.892, 0.8190000000000001, 0.8909999999999999, 0.862, 0.938, 0.9129999999999999, 0.92, 0.8859999999999999, 0.8009999999999999, 0.898, 0.8759999999999999, 0.86, 0.909, 0.8029999999999999, 0.833, 0.816, 0.8640000000000001, 0.746, 0.8, 0.9229999999999999, 0.852, 0.8059999999999999, 0.905, 0.22699999999999998, 0.925, 0.91, 0.752, 0.8859999999999999, 0.9059999999999999, 0.7140000000000001, 0.8959999999999999, 0.821, 0.934, 0.8270000000000001, 0.35700000000000004, 0.925, 0.878, 0.903, 0.862, 0.7859999999999999, 0.843, 0.418, 0.907, 0.887, 0.909, 0.8059999999999999, 0.903, 0.821, 0.851, 0.85, 0.88, 0.885, 0.9179999999999999, 0.8370000000000001, 0.9229999999999999, 0.91, 0.836, 0.8240000000000001, 0.8740000000000001, 0.868, 0.894, 0.909, 0.857,  ...

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(ncols=2, figsize=(15, 6))

absent_11.plot(kind="scatter", x="Longitude", y="Latitude", ax=axes[0],
    s=absent_11['Economic Need Index']*100, c="School Income Estimate", cmap=plt.get_cmap("jet"),label='Schools', title='Schools with 10% Absent Rate',
    colorbar=True, alpha=0.3, figsize=(15,7))

absent_30.plot(kind="scatter", x="Longitude", y="Latitude", ax=axes[1],
    s=absent_30['Economic Need Index']*100, c="School Income Estimate", cmap=plt.get_cmap("jet"),label='Schools', title='Schools with 30% Absent Rate',
    colorbar=True, alpha=0.4, figsize=(15,7))

plt.show()

# %%
# Display the Mean ELA and Math Scores for Black/Hispanic Dominant Schools
df[df['Percent Black / Hispanic'] >= .70][['Average ELA Proficiency','Average Math Proficiency']].mean()
# Out:
# Average ELA Proficiency     2.352136
# Average Math Proficiency    2.439736
# dtype: float64

# %%
# Display the Mean ELA and Math Scores for White/Asian Dominant Schools
df[df['Percent Black / Hispanic'] <= .30][['Average ELA Proficiency','Average Math Proficiency']].mean()
# Out:
# Average ELA Proficiency     3.046919
# Average Math Proficiency    3.326919
# dtype: float64

# %% [markdown]
# <a id='math_test'></a>
# # Math Test Performance By Race (Grade 3 - 8)
# ***
#
# From the graph below, **Asians and Whites** have a **higher** count of scoring **4s on their Math Test**.
#
# **Blacks and Hispanics** have a **low** count for scoring **4s on their Math Test**.

# %%
# Create the math scores for each race
asian_math = []
asian_math.append(sum(df['Grade 3 Math 4s - Asian or Pacific Islander']))
asian_math.append(sum(df['Grade 4 Math 4s - Asian or Pacific Islander']))
asian_math.append(sum(df['Grade 5 Math 4s - Asian or Pacific Islander']))
asian_math.append(sum(df['Grade 6 Math 4s - Asian or Pacific Islander']))
asian_math.append(sum(df['Grade 7 Math 4s - Asian or Pacific Islander']))
asian_math.append(sum(df['Grade 8 Math 4s - Asian or Pacific Islander']))

white_math = []
white_math.append(sum(df['Grade 3 Math 4s - White']))
white_math.append(sum(df['Grade 4 Math 4s - White']))
white_math.append(sum(df['Grade 5 Math 4s - White']))
white_math.append(sum(df['Grade 6 Math 4s - White']))
white_math.append(sum(df['Grade 7 Math 4s - White']))
white_math.append(sum(df['Grade 8 Math 4s - White']))

black_math = []
black_math.append(sum(df['Grade 3 Math 4s - Black or African American']))
black_math.append(sum(df['Grade 4 Math 4s - Black or African American']))
black_math.append(sum(df['Grade 5 Math 4s - Black or African American']))
black_math.append(sum(df['Grade 6 Math 4s - Black or African American']))
black_math.append(sum(df['Grade 7 Math 4s - Black or African American']))
black_math.append(sum(df['Grade 8 Math 4s - Black or African American']))

hispanic_math = []
hispanic_math.append(sum(df['Grade 3 Math 4s - Hispanic or Latino']))
hispanic_math.append(sum(df['Grade 4 Math 4s - Hispanic or Latino']))
hispanic_math.append(sum(df['Grade 5 Math 4s - Hispanic or Latino']))
hispanic_math.append(sum(df['Grade 6 Math 4s - Hispanic or Latino']))
hispanic_math.append(sum(df['Grade 7 Math 4s - Hispanic or Latino']))
hispanic_math.append(sum(df['Grade 8 Math 4s - Hispanic or Latino']))

# %%
# Create dataframe of math scores
race_mathscores = pd.DataFrame({'Asian Math':asian_math,'Black Math':black_math,'White Math':white_math, 'Hispanic Math':hispanic_math})
race_mathscores['Grade'] = [3,4,5,6,7,8]
race_mathscores
# Out:
#    Asian Math  Black Math  Hispanic Math  White Math  Grade
# 0        5121        2869           3581        3829      3
# 1        5024        2240           3457        3704      4
# 2        4133        1120           2115        2992      5
# 3        5456        1856           2907        3804      6
# 4        4282         951           1730        2947      7
# 5        2524         776           1205        1235      8

# %%
print('Asian scores mean', race_mathscores['Asian Math'].mean())
print('Black Math scores mean', race_mathscores['Black Math'].mean())
print('Hispanic Math scores mean', race_mathscores['Hispanic Math'].mean())
print('White Math scores mean', race_mathscores['White Math'].mean())
# Out:
# Asian scores mean 4423.333333333333
# Black Math scores mean 1635.3333333333333
# Hispanic Math scores mean 2499.1666666666665
# White Math scores mean 3085.1666666666665

# %%
# Create a trace
trace = go.Scatter(
    x = race_mathscores['Grade'],
    y = race_mathscores['Asian Math'],
    name = 'Asian Students'
)

trace2 = go.Scatter(
    x = race_mathscores['Grade'],
    y = race_mathscores['Hispanic Math'],
    name = 'Hispanic Students'
)

trace3 = go.Scatter(
    x = race_mathscores['Grade'],
    y = race_mathscores['Black Math'],
    name = 'Black Students'
)

trace4 = go.Scatter(
    x = race_mathscores['Grade'],
    y = race_mathscores['White Math'],
    name = 'White Students'
)

layout= go.Layout(
    title= 'Student Math 4s Performance By Grade (Race)',
    xaxis= dict(
        title= 'Grade Level'
    ),
    yaxis=dict(
        title='# of Students Receiving Math 4s'
    )
)

data = [trace, trace2, trace3, trace4]

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='scatter_hover_labels')
# Out:
# <div id="f7403e24-ce5a-4dfc-bbf9-cfcaf83eeea3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'f7403e24-ce5a-4dfc-bbf9-cfcaf83eeea3',
#             [{"uid": "ebcc4810-928a-11e8-ba5c-402cf46e02a7", "y": [5121.0, 5024.0, 4133.0, 5456.0, 4282.0, 2524.0], "name": "Asian Students", "x": [3.0, 4.0, 5.0, 6.0, 7.0, 8.0], "type": "scatter"}, {"uid": "ebcc4811-928a-11e8-a4f2-402cf46e02a7", "y": [3581.0, 3457.0, 2115.0, 2907.0, 1730.0, 1205.0], "name": "Hispanic Students", "x": [3.0, 4.0, 5.0, 6.0, 7.0, 8.0], "type": "scatter"}, {"uid": "ebcc4812-928a-11e8-9b6a-402cf46e02a7", "y": [2869.0, 2240.0, 1120.0, 1856.0, 951.0, 776.0], "name": "Black Students", "x": [3.0, 4.0, 5.0, 6.0, 7.0, 8.0], "type": "scatter"}, {"uid": "ebcc4813-928a-11e8-aa31-402cf46e02a7", "y": [3829.0, 3704.0, 2992.0, 3804.0, 2947.0, 1235.0], "name": "White Students", "x": [3.0, 4.0, 5.0, 6.0, 7.0, 8.0], "type": "scatter"}],
#             {"yaxis": {"title": "# of Students Receiving Math 4s"}, "xaxis": {"title": "Grade Level"}, "title": "Student Math 4s Performance By Grade (Race)"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('f7403e24-ce5a-4dfc-bbf9-cfcaf83eeea3',{});}).then(function(){Plotly.animate('f7403e24-ce5a-4dfc-bbf9-cfcaf83eeea3');})
#         });</script>

# %% [markdown]
# <a id='ela_test'></a>
# # ELA Test Performance By Race (Grade 3-8)
# ***
#
# **Asians** still dominate test performance with **ELA 4s**. What really caught my attention was the spike of score increase from **Grade 5-6** for **Asians**.
#
# Also, compared to the Math 4s, there is an **increase in performance over time** for **ELA 4s**.

# %%
# Create the math scores for each race
asian_ELA = []
asian_ELA.append(sum(df['Grade 3 ELA 4s - Asian or Pacific Islander']))
asian_ELA.append(sum(df['Grade 4 ELA 4s - Asian or Pacific Islander']))
asian_ELA.append(sum(df['Grade 5 ELA 4s - Asian or Pacific Islander']))
asian_ELA.append(sum(df['Grade 6 ELA 4s - Asian or Pacific Islander']))
asian_ELA.append(sum(df['Grade 7 ELA 4s - Asian or Pacific Islander']))
asian_ELA.append(sum(df['Grade 8 ELA 4s - Asian or Pacific Islander']))

white_ELA = []
white_ELA.append(sum(df['Grade 3 ELA 4s - White']))
white_ELA.append(sum(df['Grade 4 ELA 4s - White']))
white_ELA.append(sum(df['Grade 5 ELA 4s - White']))
white_ELA.append(sum(df['Grade 6 ELA 4s - White']))
white_ELA.append(sum(df['Grade 7 ELA 4s - White']))
white_ELA.append(sum(df['Grade 8 ELA 4s - White']))

black_ELA = []
black_ELA.append(sum(df['Grade 3 ELA 4s - Black or African American']))
black_ELA.append(sum(df['Grade 4 ELA 4s - Black or African American']))
black_ELA.append(sum(df['Grade 5 ELA 4s - Black or African American']))
black_ELA.append(sum(df['Grade 6 ELA 4s - Black or African American']))
black_ELA.append(sum(df['Grade 7 ELA 4s - Black or African American']))
black_ELA.append(sum(df['Grade 8 ELA 4s - Black or African American']))

hispanic_ELA = []
hispanic_ELA.append(sum(df['Grade 3 ELA 4s - Hispanic or Latino']))
hispanic_ELA.append(sum(df['Grade 4 ELA 4s - Hispanic or Latino']))
hispanic_ELA.append(sum(df['Grade 5 ELA 4s - Hispanic or Latino']))
hispanic_ELA.append(sum(df['Grade 6 ELA 4s - Hispanic or Latino']))
hispanic_ELA.append(sum(df['Grade 7 ELA 4s - Hispanic or Latino']))
hispanic_ELA.append(sum(df['Grade 8 ELA 4s - Hispanic or Latino']))

# %%
# Create dataframe of ELA scores
race_ELA = pd.DataFrame({'Asian ELA':asian_ELA,'Black ELA':black_ELA,'White ELA':white_ELA, 'Hispanic ELA':hispanic_ELA})
race_ELA['Grade'] = [3,4,5,6,7,8]
race_ELA
# Out:
#    Asian ELA  Black ELA  Hispanic ELA  White ELA  Grade
# 0       1714        908          1054       1743      3
# 1       3212       1716          2582       3231      4
# 2       2292        954          1536       2390      5
# 3       3422       1426          1954       2762      6
# 4       2543        866          1542       2524      7
# 5       2869       1166          1934       2457      8

# %%
# Create a trace
trace = go.Scatter(
    x = race_ELA['Grade'],
    y = race_ELA['Asian ELA'],
    name = 'Asian Students'
)

trace2 = go.Scatter(
    x = race_ELA['Grade'],
    y = race_ELA['Hispanic ELA'],
    name = 'Hispanic Students'
)

trace3 = go.Scatter(
    x = race_ELA['Grade'],
    y = race_ELA['Black ELA'],
    name = 'Black Students'
)

trace4 = go.Scatter(
    x = race_ELA['Grade'],
    y = race_ELA['White ELA'],
    name = 'White Students'
)

layout= go.Layout(
    title= 'Student ELA 4s Performance By Grade (Race)',
    xaxis= dict(
        title= 'Grade Level'
    ),
    yaxis=dict(
        title='# of Students Receiving ELA 4s'
    )
)

data = [trace, trace2, trace3, trace4]

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='scatter_hover_labels')
# Out:
# <div id="4b510305-273b-49ef-8188-6696ecc6578f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '4b510305-273b-49ef-8188-6696ecc6578f',
#             [{"uid": "15ad26b6-928b-11e8-bc00-402cf46e02a7", "y": [1714.0, 3212.0, 2292.0, 3422.0, 2543.0, 2869.0], "name": "Asian Students", "x": [3.0, 4.0, 5.0, 6.0, 7.0, 8.0], "type": "scatter"}, {"uid": "15ad26b7-928b-11e8-81c5-402cf46e02a7", "y": [1054.0, 2582.0, 1536.0, 1954.0, 1542.0, 1934.0], "name": "Hispanic Students", "x": [3.0, 4.0, 5.0, 6.0, 7.0, 8.0], "type": "scatter"}, {"uid": "15ad26b8-928b-11e8-ba17-402cf46e02a7", "y": [908.0, 1716.0, 954.0, 1426.0, 866.0, 1166.0], "name": "Black Students", "x": [3.0, 4.0, 5.0, 6.0, 7.0, 8.0], "type": "scatter"}, {"uid": "15ad26b9-928b-11e8-803d-402cf46e02a7", "y": [1743.0, 3231.0, 2390.0, 2762.0, 2524.0, 2457.0], "name": "White Students", "x": [3.0, 4.0, 5.0, 6.0, 7.0, 8.0], "type": "scatter"}],
#             {"yaxis": {"title": "# of Students Receiving ELA 4s"}, "xaxis": {"title": "Grade Level"}, "title": "Student ELA 4s Performance By Grade (Race)"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('4b510305-273b-49ef-8188-6696ecc6578f',{});}).then(function(){Plotly.animate('4b510305-273b-49ef-8188-6696ecc6578f');})
#         });</script>

# %% [markdown]
# **Community Schools:**
# - Has higher economic need index
# - Average School Income = **$38k**
# - Average % Black/Hispanic = **93%**
#
# **Not Community Schools:**
# - Has lower economic need index
# - Average School Income = **$47k**
# - Average % Black/Hispanic = **70%**

# %%
# Overview of summary (Turnover V.S. Non-turnover)
turnover_Summary = df.groupby('Community School?')
turnover_Summary[['Economic Need Index', 'School Income Estimate', 'Percent Asian','Percent Black', 'Percent Hispanic', 
                  'Percent White', 'Average ELA Proficiency', 'Average Math Proficiency']].mean()
# Out:
#                    Economic Need Index  School Income Estimate  Percent Asian  \
# Community School?
# No                            0.646713            34733.531070       0.122232
# Yes                           0.853487            11774.702632       0.025921
#
#                    Percent Black  Percent Hispanic  Percent White  \
# Community School?
# No                      0.314038          0.404289       0.138462
# Yes                     0.413158          0.525526       0.024211
#
#                    Average ELA Proficiency  Average Math Proficiency
# Community School?
# No                                2.560298                  2.706322
# Yes                               2.137067                  2.100000

# %% [markdown]
# # School Income VS Economic Need Index
# ***
#
# There is definitely a negative correlation between School Income and their Economic Need Index. It makes sense:
# - The less income you make the higher economic need index you'll get.
# - The more income you make the less economic need index you'll get.

# %%
# Let's normalize the School Income Estimate to have better visualization
from sklearn import preprocessing

# Impute the missing Income with the median
median = df['School Income Estimate'].median()
df['School Income Estimate'] = df['School Income Estimate'].fillna(median)

# Create x, where x the 'scores' column's values as floats
x = df[['School Income Estimate']].values.astype(float)

# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(x)

# Run the normalizer on the dataframe
school_income_normalized = pd.DataFrame(x_scaled)

df['school_income_normalized'] = school_income_normalized

# %%
sns.lmplot(x='school_income_normalized', y='Economic Need Index', data=df,
           fit_reg=False) # No regression line

# %% [markdown]
# <a id='avg_school_income_comparison'></a>
# # Average School Income Comparison
# ***

# %% [markdown]
# **Interesting Find:** Looks like the breaking point for school income of **Community Schools** are at around **$50k**
#
# **Interesting Find:** **Non Community Schools** receive an income up to **over $175k**!

# %%
#KDEPlot: Kernel Density Estimate Plot
fig = plt.figure(figsize=(15,4))
ax=sns.kdeplot(df.loc[(df['Community School?'] == 'Yes'),'School Income Estimate'] , color='b',shade=True, label='Community School')
ax=sns.kdeplot(df.loc[(df['Community School?'] == 'No'),'School Income Estimate'] , color='r',shade=True, label='Not Community School')
plt.title('Community School VS Not Community School Income')
# Out:
# Text(0.5,1,'Community School VS Not Community School Income')

# %% [markdown]
# <a id='economic_need'></a>
# # Economic Need Index Distribution
# ***
#
# **Interesting Find:**
#
# **Community Schools** definitely need more help and a majority of them are within the **Economic Need Index** of **90%**.
#
# **Non Community Schools** have a wide distribution of their Economic Need Index scores, having a majority at the **80%** score.

# %%
#KDEPlot: Kernel Density Estimate Plot
fig = plt.figure(figsize=(15,4))
ax=sns.kdeplot(df.loc[(df['Community School?'] == 'Yes'),'Economic Need Index'] , color='b',shade=True, label='Community School')
ax=sns.kdeplot(df.loc[(df['Community School?'] == 'No'),'Economic Need Index'] , color='r',shade=True, label='Not Community School')
plt.xlabel('Economic Need Index Score')
plt.ylabel('Kernel Density Frequency')
plt.title('Community School VS Not Community School Economic Need Index')
# Out:
# Text(0.5,1,'Community School VS Not Community School Economic Need Index')

# %% [markdown]
# <a id='school_per_city'></a>
# # Number of Schools Per City / Borough
# ***
#
# The **Top 3 Cities** with the most schools are:
# 1. **Brooklyn**: 411
# 2. **Bronx**: 297
# 3. **New York **: 232

# %%
city = df.groupby('City')['Zip'].count().reset_index().sort_values('Zip', ascending=False).reset_index(drop=True)
city_community = df[df['Community School?'] == 'Yes'].groupby('City')['Zip'].count().reset_index().sort_values('Zip', ascending=False).reset_index(drop=True)

city_merge = pd.merge(city, city_community, how='left', on='City')
city_merge.fillna(0, inplace=True)
city_merge['Zip_y'] = city_merge['Zip_y'].astype(int)

top_10_city = city_merge.iloc[:10,]
top_10_city = top_10_city.rename(columns={"Zip_x":'Total Count', "Zip_y":'Community Count'})
top_10_city
# Out:
#                   City  Total Count  Community Count
# 0             BROOKLYN          411               24
# 1                BRONX          297               34
# 2             NEW YORK          232               12
# 3        STATEN ISLAND           60                1
# 4              JAMAICA           32                1
# 5             FLUSHING           30                0
# 6     LONG ISLAND CITY           21                1
# 7              BAYSIDE           13                0
# 8         FAR ROCKAWAY           13                2
# 9  SPRINGFIELD GARDENS           11                0

# %% [markdown]
# ### Top 10 Schools Per City Distribution

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(13, 7))

# Plot the total schools per city
sns.set_color_codes("pastel")
sns.barplot(x="Total Count", y='City', data=top_10_city,
            label="Total", color="b")

# Plot the total community schools per city
sns.set_color_codes("muted")
sns.barplot(x="Community Count", y="City", data=top_10_city,
            label="Community School", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 411), ylabel="City Name", title='Number of Schools Per City',
       xlabel="# of Schools")
sns.despine(left=True, bottom=True)

# %% [markdown]
# ## Top 10 Cities and School Income

# %%
top10_city_list = list(top_10_city.City)

temp=df[df.City.isin(top10_city_list)]
plt.figure(figsize=(10,8))
sns.boxplot( x='School Income Estimate', y='City',data=temp)
plt.title("School Income For The Top 10 Schools", fontsize=16)
plt.xlabel("School Income Estimate", fontsize=16)
plt.ylabel("School Name", fontsize=16)
plt.show();

# %% [markdown]
# # SHSAT Registration Content
# ***

# %%
shsat.head(3)
# Out:
#       DBN             School name  Year of SHST  Grade level  \
# 0  05M046  P.S. 046 Arthur Tappan          2013            8
# 1  05M046  P.S. 046 Arthur Tappan          2014            8
# 2  05M046  P.S. 046 Arthur Tappan          2015            8
#
#    Enrollment on 10/31  Number of students who registered for the SHSAT  \
# 0                   91                                               31
# 1                   95                                               26
# 2                   73                                               21
#
#    Number of students who took the SHSAT
# 0                                     14
# 1                                      7
# 2                                     10

# %% [markdown]
# # Total SHSAT Registration Count Per School (2013-2016)
# ***
#
# **Interesting Find:**
# - The most registration for the SHSAT occurred in **2014** with a count of **838** registrations.
# - The top 3 schools that registered for the SHSAT were from **KIPP, Columbia Secondary School, and Democracy Prep**.

# %% [markdown]
# <a id='registration_per_year'></a>
# ### Total Registrations Per Year
#
# Year **2014** has the highest amount of registrations at **838**, but then it falls off in the following years.

# %%
registration_per_year = pd.DataFrame(shsat.groupby('Year of SHST')['Number of students who registered for the SHSAT'].sum()).reset_index()
registration_per_year
# Out:
#    Year of SHST  Number of students who registered for the SHSAT
# 0          2013                                              660
# 1          2014                                              838
# 2          2015                                              597
# 3          2016                                              575

# %%
# Testing...
shsat_schools = list(shsat['DBN'].unique())
shsat_schools_list = '|'.join(shsat_schools)

df['Registered SHSAT'] = df['Location Code'].str.contains(shsat_schools_list)

registered_SHSAT_schools = df[df['Registered SHSAT'] == True]
registered_SHSAT_schools.groupby('School Name').mean()

registered_SHSAT_schools.plot(kind="scatter", x="Longitude", y="Latitude",
    s=absent_11['Economic Need Index']*100, c="School Income Estimate", cmap=plt.get_cmap("jet"),label='Schools', title='Schools with 10% Absent Rate',
    colorbar=True, alpha=0.3, figsize=(15,7))

# %%
plt.figure(figsize=(10,6))
sns.barplot(y=registration_per_year['Number of students who registered for the SHSAT'], x=registration_per_year['Year of SHST'], alpha=0.6)
plt.title("Number of SHSAT Registrations Per Year", fontsize=16)
plt.xlabel("Year", fontsize=16)
plt.ylabel("# of SHSAT Registration", fontsize=16)
plt.show()

# %% [markdown]
# <a id='registration_count'></a>
# # Registration Count Per School Distribution
# ***
#
# ### Top 10 Schools With The Most Registrations

# %%
# Create a dataframe of # of students who took the SHSAT
school_take = shsat.groupby('School name')['Number of students who took the SHSAT'].sum().reset_index().sort_values('Number of students who took the SHSAT', ascending=False).reset_index(drop=True)

# Create a dataframe of SHSAT Registration Count
school_registrations = shsat.groupby('School name')['Number of students who registered for the SHSAT'].sum().reset_index().sort_values('Number of students who registered for the SHSAT', ascending=False).reset_index(drop=True)

# Merge the DataFrames
registration_merge = pd.merge(school_registrations, school_take, how='left', on='School name')
registration_merge.head(10)
# Out:
#                                 School name  \
# 0              KIPP Infinity Charter School
# 1     KIPP STAR College Prep Charter School
# 2                 Columbia Secondary School
# 3   Democracy Prep Endurance Charter School
# 4             Democracy Prep Charter School
# 5                Frederick Douglass Academy
# 6  I.S. M286 Renaissance Leadership Academy
# 7                   P.S. 129 John H. Finley
# 8                    P.S. 046 Arthur Tappan
# 9                                  KAPPA IV
#
#    Number of students who registered for the SHSAT  \
# 0                                              296
# 1                                              292
# 2                                              253
# 3                                              194
# 4                                              145
# 5                                              122
# 6                                              109
# 7                                              108
# 8                                               98
# 9                                               97
#
#    Number of students who took the SHSAT
# 0                                     65
# 1                                     96
# 2                                    179
# 3                                     94
# 4                                    100
# 5                                     65
# 6                                     28
# 7                                     48
# 8                                     39
# 9                                     40

# %% [markdown]
# # SHSAT Registration Distribution Per School
# ***
#
# Below is the distribution of SHSAT Registrations and the amount of students who actually took it.
#
# It's really interesting to see the actual amount of students who took the test and registered.
#
# **Why is it that some schools have a higher Take-to-Register rate?**

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

# Plot the total schools per city
sns.set_color_codes("pastel")
sns.barplot(x="Number of students who registered for the SHSAT", y='School name', data=registration_merge,
            label="# of SHSAT Registrations", color="g")

# Plot the total community schools per city
sns.set_color_codes("muted")
sns.barplot(x="Number of students who took the SHSAT", y="School name", data=registration_merge,
            label="# of Students who Took SHSAT", color="g")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 300), ylabel="School Name", title='SHSAT School Registration Distribution',
       xlabel="# of Registrations")
sns.despine(left=True, bottom=True)

# %% [markdown]
# <a id='clustering'></a>
# # K-Means Clustering: School Economic Need and Income Estimate
# ***
# Let's see if there is any sort of cluster of schools:
#
# - **Critical Help (Red)**: Schools in red have a high economic need with an **Estimate Income < 50,000**
# - **Moderate Help (Green)**: Schools in green have a low-moderate economic need with an **Estimate Income < 50,000-75,000**
# - **Low Help (Blue)**: Schools in blue have a low economic need with an **Estimate Income > 75,000**

# %% [markdown]
# ### Elbow Plot: Three Cluster seems to be the magic number

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

df_zero = df[df['Economic Need Index'] != 0]
df_zero2 = df_zero[df_zero['School Income Estimate'] != 0]

data = df_zero2[['Economic Need Index', 'School Income Estimate']]

sse = {}
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(data)
    data["clusters"] = kmeans.labels_
    #print(data["clusters"])
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# ### K-Means Clustering

# %%
# Import KMeans Model
from sklearn.cluster import KMeans

# Graph and create 3 clusters of Employee Turnover
kmeans = KMeans(n_clusters=3,random_state=2)
kmeans.fit(df_zero2[["Economic Need Index","School Income Estimate"]])

kmeans_colors = ['green' if c == 0 else 'red' if c == 2 else 'yellow' if c == 3 else 'blue' for c in kmeans.labels_]

fig = plt.figure(figsize=(10, 6))
plt.scatter(x="Economic Need Index",y="School Income Estimate", data=df_zero2,
            alpha=0.25,color = kmeans_colors)
plt.xlabel("Economic Need Index")
plt.ylabel("School Income Estimate")
plt.scatter(x=kmeans.cluster_centers_[:,0],y=kmeans.cluster_centers_[:,1],color="black",marker="X",s=100)
plt.title("Clusters of School Economic Need & Income Estimate")
plt.show()

# %% [markdown]
# # Final Note
# ***
#
# Here are some key takeaways:
#
# ### Geography
# - **Central and Upper** New York have schools that are mostly in need of help
# - **Central and Upper** New York contains most of the **underperforming students**
#
# ### Race
# - Majority of **Blacks** attend schools in the **Central** part of New York
# - Majority of **Hispanics** attend schools in the **Upper** part of New York
# - Schools with **30% or more** Absent Rate have an average of **95% Black/Hispanic Dominated Schools**
# - On average, **Black/Hispanic** have a lower **ELA & Math** Performance Scores than **White/Asian**
# - Overall, **Asians** received the most **4s** in **ELA and Math Performance**.
#
# ### Conclusion
# To keep it short:
# - **Services** are needed for mostly the **Hispanic/Black** student population
# - Which are **located** mostly in **Central and Upper** Parts of New York.
